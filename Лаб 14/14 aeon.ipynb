# %% [markdown]
# # AEON

# %% [markdown]
# В этой лекции мы более подробно поработаем с библиотекой aeon
#
# Aeon — это совместимый с scikit-learn набор инструментов для работы с временными рядами (TSML). Он организован в
# модули для различных задач обучения: классификация, регрессия, кластеризация, прогнозирование, обнаружение аномалий, сегментация и поиск по сходству.
#
# Aeon - хорошо документированная библиотека, имеет большое количество блокнотов, доступных в [документации](https://www.aeon-toolkit.org/en/stable/). Эта работа составлена на основе блокнотов, представленных в руководстве.
#
# Будем использовать для примера наборы данных ЭЭГ. Все используемые типы данных представляют собой трехмерные массивы (3D numpy arrays).

# %% [markdown]
# # Структуры данных и наборы данных
#
# *aeon* предполагает, что один временной ряд представляет собой двумерный массив формы `(n_channels, n_timepoints)`.
#
# Классификаторы и регрессоры принимают входные коллекции временных рядов (и наследуют от BaseCollectionEstimator).
#
# Если все серии имеют одинаковую длину, лучше всего работает с трехмерной фигурой `(n_cases, n_channels, n_timepoints)`.
#
# Серии разной длины хранятся в списках 2D numpy, но примеры, которые мы собираемся использовать, будут иметь одинаковую длину.
#
# В этом уроке в качестве рабочего примера будут использоваться данные ЭЭГ.
#
# Классификационный набор данных состоит из показаний ЭЭГ, снятых у испытуемого в состоянии покоя или при выполнении заданной задачи (поднятие рук). Полную информацию об этих данных можно найти в [блокноте](https://github.com/aeon-toolkit/aeon-neuro/blob/main/examples/data_loading.ipynb).
#
# *aeon* поставляется с некоторыми стандартными наборами данных UCR и UEA, и их все можно загрузить непосредственно с [timeseriesclassification.com](https://timeseriesclassification.com).

# %% [markdown]
# # Содержание
#
# * [Меры расстояний](#distance-tsc)
# * [Distance-based univariate Time Series Classification (TSC)](#classification)
# * [Distance-based  Time Series Extrinsic Regression](#regres)
# * [Подходы, основанные на свертках](#conv)
# * [Feature based classification and regression](#feature)
# * [Deep Learning подходы](#deep)
# * [Упражнения](#tasks)

# %% [markdown]
# ## Меры расстояний  <a id="distance-tsc"></a>
# Подходы, основанные на сходстве, были одним из первых предложений по классификации и регрессии временных рядов. Более того, эти типы методов также распространены для выполнения других задач временных рядов, таких как кластеризация или обнаружение аномалий и других.
#
# В первой части этой тетради представлены расстояния, реализованные в эоне, начиная с самого простого — евклидова расстояния. Затем он представляет расстояние динамического искажения времени (DTW), его варианты, такие как Amerced DTW (ADTW) или Shape DTW (ShapeDTW), а также некоторые другие альтернативные расстояния, такие как Move-Split-Merge (MSM).
#
# Во второй части этого блокнота мы демонстрируем использование этих расстояний в сочетании с классификатором KNearestNeighbours из scikit-learn, а также более подходящую реализацию KNearestNeighbours для временных рядов, включенных в aeon. Аналогичным образом также представлены подходы к работе с наборами данных TSER с использованием дистанционных подходов.
#
# Документация aeon содержит записные книжки по   [растоянию](https://www.aeon-toolkit.org/en/stable/examples/distances/distances.html) and [классификации на основе дистанции](https://www.aeon-toolkit.org/en/stable/examples/classification/distance_based.html) и искользования `aeon` расстояних с [`scikit-learn`](https://www.aeon-toolkit.org/en/stable/examples/distances/sklearn_distances.html).

# %%
# %pip install aeon[all_extras]
# %mkdir -p dataset
# Out:
# Requirement already satisfied: aeon[all_extras] in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (1.3.0)
# Requirement already satisfied: deprecated>=1.2.13 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (1.3.1)
# Requirement already satisfied: numba<0.62.0,>=0.55 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (0.61.2)
# Requirement already satisfied: numpy<2.3.0,>=1.21.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (26.0)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (2.3.3)
# Requirement already satisfied: scikit-learn<1.8.0,>=1.0.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (1.7.2)
# Requirement already satisfied: scipy<1.16.0,>=1.9.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (1.15.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (4.15.0)
# Requirement already satisfied: esig>=1.0.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (1.0.0)
# Requirement already satisfied: imbalanced-learn in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (0.14.1)
# Requirement already satisfied: matplotlib>=3.3.2 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (3.10.8)
# Requirement already satisfied: pycatch22>=0.4.5 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (0.4.5)
# Requirement already satisfied: pyod>=1.1.3 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (2.0.7)
# Requirement already satisfied: pydot>=2.0.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (4.0.1)
# Requirement already satisfied: seaborn>=0.11.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (0.13.2)
# Requirement already satisfied: sparse in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (0.17.0)
# Requirement already satisfied: statsmodels>=0.12.1 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (0.14.6)
# Requirement already satisfied: stumpy>=1.5.1 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (1.14.1)
# Requirement already satisfied: tensorflow>=2.14 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (2.21.0)
# Requirement already satisfied: keras>=3.6.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (3.12.1)
# Requirement already satisfied: torch>=1.13.1 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (2.11.0)
# Requirement already satisfied: tsfresh>=0.20.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (0.21.1)
# Requirement already satisfied: tslearn>=0.5.2 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from aeon[all_extras]) (0.8.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from numba<0.62.0,>=0.55->aeon[all_extras]) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from pandas<2.4.0,>=2.0.0->aeon[all_extras]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from pandas<2.4.0,>=2.0.0->aeon[all_extras]) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from pandas<2.4.0,>=2.0.0->aeon[all_extras]) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from scikit-learn<1.8.0,>=1.0.0->aeon[all_extras]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from scikit-learn<1.8.0,>=1.0.0->aeon[all_extras]) (3.6.0)
# Requirement already satisfied: wrapt<3,>=1.10 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from deprecated>=1.2.13->aeon[all_extras]) (2.1.2)
# Requirement already satisfied: pyrecombine in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from esig>=1.0.0->aeon[all_extras]) (1.0.1)
# Requirement already satisfied: roughpy in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from esig>=1.0.0->aeon[all_extras]) (0.2.0)
# Requirement already satisfied: absl-py in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from keras>=3.6.0->aeon[all_extras]) (2.4.0)
# Requirement already satisfied: rich in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from keras>=3.6.0->aeon[all_extras]) (14.3.3)
# Requirement already satisfied: namex in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from keras>=3.6.0->aeon[all_extras]) (0.1.0)
# Requirement already satisfied: h5py in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from keras>=3.6.0->aeon[all_extras]) (3.14.0)
# Requirement already satisfied: optree in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from keras>=3.6.0->aeon[all_extras]) (0.19.0)
# Requirement already satisfied: ml-dtypes in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from keras>=3.6.0->aeon[all_extras]) (0.5.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from matplotlib>=3.3.2->aeon[all_extras]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from matplotlib>=3.3.2->aeon[all_extras]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from matplotlib>=3.3.2->aeon[all_extras]) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from matplotlib>=3.3.2->aeon[all_extras]) (1.5.0)
# Requirement already satisfied: pillow>=8 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from matplotlib>=3.3.2->aeon[all_extras]) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from matplotlib>=3.3.2->aeon[all_extras]) (3.3.2)
# Requirement already satisfied: six>=1.5 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=2.0.0->aeon[all_extras]) (1.17.0)
# Requirement already satisfied: patsy>=0.5.6 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from statsmodels>=0.12.1->aeon[all_extras]) (1.0.2)
# Requirement already satisfied: astunparse>=1.6.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tensorflow>=2.14->aeon[all_extras]) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tensorflow>=2.14->aeon[all_extras]) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tensorflow>=2.14->aeon[all_extras]) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tensorflow>=2.14->aeon[all_extras]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tensorflow>=2.14->aeon[all_extras]) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tensorflow>=2.14->aeon[all_extras]) (3.4.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tensorflow>=2.14->aeon[all_extras]) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tensorflow>=2.14->aeon[all_extras]) (2.33.1)
# Requirement already satisfied: setuptools in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tensorflow>=2.14->aeon[all_extras]) (57.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tensorflow>=2.14->aeon[all_extras]) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tensorflow>=2.14->aeon[all_extras]) (1.80.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.14->aeon[all_extras]) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.14->aeon[all_extras]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.14->aeon[all_extras]) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.14->aeon[all_extras]) (2026.2.25)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow>=2.14->aeon[all_extras]) (0.46.3)
# Requirement already satisfied: filelock in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from torch>=1.13.1->aeon[all_extras]) (3.25.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from torch>=1.13.1->aeon[all_extras]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from torch>=1.13.1->aeon[all_extras]) (3.4.2)
# Requirement already satisfied: jinja2 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from torch>=1.13.1->aeon[all_extras]) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from torch>=1.13.1->aeon[all_extras]) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.13.1->aeon[all_extras]) (1.3.0)
# Requirement already satisfied: pywavelets in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tsfresh>=0.20.0->aeon[all_extras]) (1.8.0)
# Requirement already satisfied: tqdm>=4.10.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tsfresh>=0.20.0->aeon[all_extras]) (4.67.3)
# Requirement already satisfied: cloudpickle in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tsfresh>=0.20.0->aeon[all_extras]) (3.1.2)
# Requirement already satisfied: colorama in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from tqdm>=4.10.0->tsfresh>=0.20.0->aeon[all_extras]) (0.4.6)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from imbalanced-learn->aeon[all_extras]) (0.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from jinja2->torch>=1.13.1->aeon[all_extras]) (3.0.3)
# Requirement already satisfied: intel_openmp in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from pyrecombine->esig>=1.0.0->aeon[all_extras]) (2025.3.3)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.3.3 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from intel_openmp->pyrecombine->esig>=1.0.0->aeon[all_extras]) (2025.3.3)
# Requirement already satisfied: umf==1.0.* in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from intel-cmplr-lib-ur==2025.3.3->intel_openmp->pyrecombine->esig>=1.0.0->aeon[all_extras]) (1.0.3)
# Requirement already satisfied: tcmlib>=1.4 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from umf==1.0.*->intel-cmplr-lib-ur==2025.3.3->intel_openmp->pyrecombine->esig>=1.0.0->aeon[all_extras]) (1.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from rich->keras>=3.6.0->aeon[all_extras]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from rich->keras>=3.6.0->aeon[all_extras]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in d:\users\elise\onedrive\рабочий стол\учёба\магистратура\2 триместр\регрессионный анализ\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.6.0->aeon[all_extras]) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# �������� ��� 䠩� -p 㦥 �������.
# �訡�� �� �६� ��ࠡ�⪨: -p.
# �������� ��� 䠩� dataset 㦥 �������.
# �訡�� �� �६� ��ࠡ�⪨: dataset.

# %% [markdown]
# Чтобы использовать следующие команды, нужно убедиться, что wget установлен в вашей системе
# Скачать нужную версию wget можно с официального сайта  https://eternallybored.org/misc/wget/
# После скачивания - положить wget.exe сюда C:\Windows\System32
#
# Проблема windows еще и в том, что в powershell установлены allias  для iwr, curl, wget. При попытке к запустить эти команды будет запускаться виндовская Invoke-WebRequest .
# Поэтому или запускать с указанием расширения (например, wget.exe), или измненить алиас. Сделать это можно следующим образом.
#
# 1. Запускаем powershell или cmd.
#
# 2. Смотрим, что привязано к комманде wget:
# Get-Alias -Name wget
#
# 3. Если видите ответ типа "Alias           wget -> Invoke-WebRequest", то удаляем алиас:
# Remove-Item -Path Alias:\wget
#
# 4. Проверяем командой 2. Должно выдать ошибку.
#
# 5. Устанавливаем новый алиас
# New-Alias wget wget.exe
#
# Все, спокойно пользуемся привычным wget - ом.

# %%
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSC_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSC_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSC_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSC_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSER_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSER_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSER_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSER_TEST.ts -P dataset/
# Out:
# File 'dataset/KDD_MTSC_TRAIN.ts' already there; not retrieving.
#
# File 'dataset/KDD_MTSC_TEST.ts' already there; not retrieving.
#
# File 'dataset/KDD_UTSC_TRAIN.ts' already there; not retrieving.
#
# File 'dataset/KDD_UTSC_TEST.ts' already there; not retrieving.
#
# File 'dataset/KDD_MTSER_TRAIN.ts' already there; not retrieving.
#
# File 'dataset/KDD_MTSER_TEST.ts' already there; not retrieving.
#
# File 'dataset/KDD_UTSER_TRAIN.ts' already there; not retrieving.
#
# File 'dataset/KDD_UTSER_TEST.ts' already there; not retrieving.

# %%
# это опционально, если хотите видеть все ворнинги - не запускайте эту ячейку

import warnings

warnings.filterwarnings("ignore")

# %%
from aeon.datasets import load_from_ts_file

# Загрузите одномерный набор данных TSC как двумерный массив NumPy

X_train_utsc, y_train_utsc = load_from_ts_file("./dataset/KDD_UTSC_TRAIN.ts", return_type="numpy2D")
X_test_utsc, y_test_utsc = load_from_ts_file("./dataset/KDD_UTSC_TEST.ts", return_type="numpy2D")

print("Single channel EEG TSC problem train shape:", X_train_utsc.shape)
print("Single channel EEG TSC problem test shape:", X_test_utsc.shape)
# Out:
# Single channel EEG TSC problem train shape: (40, 100)
# Single channel EEG TSC problem test shape: (40, 100)

# %%
# Загрузите многомерный набор данных в виде трехмерного массива numpy

X_train_mtsc, y_train_mtsc = load_from_ts_file("./dataset/KDD_MTSC_TRAIN.ts")
X_test_mtsc, y_test_mtsc = load_from_ts_file("./dataset/KDD_MTSC_TEST.ts")

print("Four channel EEG TSC problem train shape:", X_train_mtsc.shape)
print("Four channel EEG TSC problem test shape:", X_test_mtsc.shape)
# Out:
# Four channel EEG TSC problem train shape: (40, 4, 100)
# Four channel EEG TSC problem test shape: (40, 4, 100)

# %%
# Загрузите одномерный набор данных TSER как двумерный массив numpy
X_train_utser, y_train_utser = load_from_ts_file("./dataset/KDD_UTSER_TRAIN.ts", return_type="numpy2D")
X_test_utser, y_test_utser = load_from_ts_file("./dataset/KDD_UTSER_TEST.ts", return_type="numpy2D")

print("Single channel EEG TSER problem train shape:", X_train_utsc.shape)
print("Single channel EEG TSER problem test shape:", X_test_utsc.shape)
# Out:
# Single channel EEG TSER problem train shape: (40, 100)
# Single channel EEG TSER problem test shape: (40, 100)

# %%
# Загрузите многомерный набор данных TSER в виде трехмерного массива numpy
X_train_mtser, y_train_mtser = load_from_ts_file("./dataset/KDD_MTSER_TRAIN.ts")
X_test_mtser, y_test_mtser = load_from_ts_file("./dataset/KDD_MTSER_TEST.ts")

print("Four channel EEG TSER problem train shape:", X_train_mtser.shape)
print("Four channel EEG TSER problem test shape:", X_test_mtser.shape)
# Out:
# Four channel EEG TSER problem train shape: (72, 4, 100)
# Four channel EEG TSER problem test shape: (72, 4, 100)

# %% [markdown]
# Для наших примеров измерения расстояния давайте определим два разных случайных одномерных временных ряда (a и b) длиной m=10 и построим их график.

# %%
from aeon.testing.data_generation import make_example_1d_numpy
import seaborn as sns
import matplotlib.pyplot as plt

a = make_example_1d_numpy(n_timepoints=10, random_state=0)
b = make_example_1d_numpy(n_timepoints=10, random_state=1)

sns.lineplot(data=a, label=r"$\mathbf{a}$")
sns.lineplot(data=b, label=r"$\mathbf{b}$")

plt.show()

# %% [markdown]
# #### Euclidean Distance (direct alignment)

# %%
# Считаем по формуле вручную

import numpy as np

ED = np.sqrt(np.sum(np.power(a-b,2)))

print(f"The Euclidean distance between a and b is {ED}")
# Out:
# The Euclidean distance between a and b is 1.236743116180222

# %%
# Используем aeon

from aeon.distances import euclidean_distance

print(
    f"The Euclidean distance computed in aeon between a and b is",
    f"{euclidean_distance(a, b)}"
)
# Out:
# The Euclidean distance computed in aeon between a and b is 1.236743116180222

# %%
# Постройте расстояния временных рядов поточечно, следуя по пути.
def plot_time_series_distances(a, b, cost_matrix, path):
    sns.lineplot(data=a, label=r"$\mathbf{a}$")
    sns.lineplot(data=b, label=r"$\mathbf{b}$")

    # соединить точки на пути
    for i in range(len(path)):
        plt.plot(
            [path[i][0], path[i][1]],
            [a[path[i][0]], b[path[i][1]]],
            'k--',
            alpha=0.2
        )
        plt.text(
            (path[i][0]+path[i][1])/2,
            (a[path[i][0]]+b[path[i][1]])/2,
            f"{cost_matrix[path[i][0], path[i][1]]:.2f}"
        )

    return plt

# Вычислите квадрат матрицы расстояний между a и b.
def squared_pointwise_distance(a, b):
    n_timesteps = len(a)
    distances_matrix = np.zeros((n_timesteps, n_timesteps))

    for i in range(n_timesteps):
        for j in range(n_timesteps):
            distances_matrix[i, j] = (a[i]-b[j])**2

    return distances_matrix


cost_matrix = squared_pointwise_distance(a,b)
path = [(i, i) for i in range(len(a))]

ax = plot_time_series_distances(a, b, cost_matrix, path)

plt.show()

# %% [markdown]
# Евклидово расстояние также можно определить как квадратный корень из суммы квадратов разностей значений на диагонали всех возможных расстояний между элементами в обоих временных рядах.
#
# Прежде всего, мы вычисляем матрицу расстояний, которая содержит расстояния для всех элементов обоих временных рядов:

# %%
from aeon.visualisation.distances._pairwise_distance_matrix import plot_pairwise_distance_matrix

# Compute the squared pointwise distances between a and b
distance_matrix = squared_pointwise_distance(a, b)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(distance_matrix, a, b, path)
plt.show()

# %% [markdown]
# #### Гибкое расстояние: динамическое искажение времени (DTW)
#  DTW допускает выравнивание по временным шагам, т. е. не обязательно выравнивать временные шаги, а только первый и последний временные шаги.
#
# В этом первом примере мы позволяем DTW иметь последовательные выравнивания, продвигающиеся не более чем на один временной шаг в каждой серии.

# %%
from aeon.distances import dtw_distance

print(
    f"The DTW distance computed in aeon between a and b is",
    f"{dtw_distance(a, b, window=0.1)}"
)
# Out:
# The DTW distance computed in aeon between a and b is 1.1985498275436108

# %%
from aeon.distances import dtw_alignment_path, dtw_cost_matrix

path, _ = dtw_alignment_path(a, b, window=0.1)
cost_matrix = dtw_cost_matrix(a, b, window=0.1)

sns.lineplot(data=a, label=r"$\mathbf{a}$")
sns.lineplot(data=b, label=r"$\mathbf{b}$")

# join the points in the path
for i in range(len(path)):
    plt.plot([path[i][0], path[i][1]], [a[path[i][0]], b[path[i][1]]], 'k--', alpha=0.2)
    plt.text(
        (path[i][0]+path[i][1])/2,
        (a[path[i][0]]+b[path[i][1]])/2,
        f"{cost_matrix[path[i][0], path[i][1]]:.2f}"
    )

plt.show()

# %% [markdown]
# Сравните графики DTW и декартового расстояния. Какие выводы?

# %% [markdown]
# Как можно заметить, теперь расстояния не вычисляются для одних и тех же моментов времени. Они
# рассчитываются с учетом коллиндантных моментов времени.
#
# В этом случае расстояние — это путь с минимальной стоимостью, который удовлетворяет вышеупомянутым условиям.
#
# Ограничения:
#
# (Обратите внимание, что для удобства чтения пути начальная позиция должна быть последней,
# в данном случае (9,9), и мы перемещаем ближайшую точку времени. Например, из (9,9) мы
# может перейти в: A) (8, 9) со стоимостью 1,32, B) (8, 8) со стоимостью 1,32 или C) (9, 8)
# со стоимостью 1,17. Последнее - правильный выбор.)

# %%
path, dtw_dist = dtw_alignment_path(a, b, window=0.1)
print(f"DTW distance between a and b is {dtw_dist}.")
# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=0.1)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance between a and b is 1.1985498275436108.

# %% [markdown]
# Важно знать, что  DTW может быть более терпимой и предоставлять более широкие возможности выравнивания временных рядов. Чтобы контролировать такое поведение, мы определяем еще одно ограничение: размер окна.
#
# Это ограничение окон позволяет избежать выравнивания точек, разделенных более чем определенным процентом от длины временного ряда. Другими словами, если ограничение окна равно $w$, выравнивание $i$-й точки можно выполнить только с точками из интервала
#
# $[i - \lfloor w*m \rfloor, i + \lfloor w*m \rfloor]$.
#
# В предыдущем сценарии не использовался размер окна (эквивалент ограничения окна $w=1$.).
#
# Теперь, если мы уменьшим длину окна до $w=0,5$, мы увидим, что путь изменился:

# %%
w = 0.5
path, dtw_dist = dtw_alignment_path(a, b, window=w)
print(f"DTW distance with {w=} between a and b is {dtw_dist}.")

# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=w)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance with w=0.5 between a and b is 0.8566491595090396.

# %% [markdown]
# Посмотрим, что будет при ограничении окна в 20%.

# %%
w = 0.2
path, dtw_dist = dtw_alignment_path(a, b, window=w)
print(f"DTW distance with {w=} between a and b is {dtw_dist}.")

# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=w)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance with w=0.2 between a and b is 0.9199809594402144.

# %% [markdown]
# Можем посмотреть, какие варианты DTW реализованы в aeon. И сравнить получаемые расстояния.

# %%
from aeon.distances._distance import DISTANCES

# These are the DTW variants available in aeon for time series:
dtw_variants = [d["name"] for d in DISTANCES if 'dtw' in d["name"]]
print(f"DTW variants available in aeon: {dtw_variants}")
# Out:
# DTW variants available in aeon: ['dtw', 'dtw_gi', 'ddtw', 'wdtw', 'wddtw', 'adtw', 'shape_dtw', 'soft_dtw']

# %%
from aeon.distances import get_distance_function

for variant in dtw_variants:
    distance_function = get_distance_function(variant)
    distance = distance_function(a, b, window=0.2)
    print(f"{variant} distance between a and b is {distance}")
# Out:
# dtw distance between a and b is 0.9199809594402144
# dtw_gi distance between a and b is 0.9199809594402144
# ddtw distance between a and b is 0.31002884948727205
# wdtw distance between a and b is 0.41867594005282865
# wddtw distance between a and b is 0.13960840776560768
# adtw distance between a and b is 1.5295335354191664
# shape_dtw distance between a and b is 1.5295335354191666
# soft_dtw distance between a and b is 11.074455734012375

# %% [markdown]
# Посмотрим, какие вообще метрики расстояния раелизованы в aeon и сравним их.

# %%
for dist in DISTANCES:
    try:
        print(f"{dist['name']} distance between a and b is {dist['distance'](a, b)}")
    except TypeError as err:
        print(f"{dist['name']} - {err}")
# Out:
# euclidean distance between a and b is 1.236743116180222
# squared distance between a and b is 1.5295335354191664
# manhattan distance between a and b is 3.3323904398054873
# minkowski distance between a and b is 1.2367431161802223
# dtw distance between a and b is 0.6574923997015053
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 for dist in DISTANCES:
#       2     try:
# ----> 3         print(f"{dist['name']} distance between a and b is {dist['distance'](a, b)}")
#       4     except TypeError as err:
#       5         print(f"{dist['name']} - {err}")
#
# File d:\Users\elise\OneDrive\Рабочий стол\Учёба\Магистратура\2 триместр\Регрессионный анализ\.venv\lib\site-packages\numba\core\dispatcher.py:376, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     374 return_val = None
#     375 try:
# --> 376     return_val = self.compile(tuple(argtypes))
#     377 except errors.ForceLiteralArg as e:
#     378     # Received request for compiler re-entry with the list of arguments
#     379     # indicated by e.requested_args.
#     380     # First, check if any of these args are already Literal-ized
#     381     already_lit_pos = [i for i in e.requested_args
#     382                        if isinstance(args[i], types.Literal)]
#
# File d:\Users\elise\OneDrive\Рабочий стол\Учёба\Магистратура\2 триместр\Регрессионный анализ\.venv\lib\site-packages\numba\core\dispatcher.py:885, in Dispatcher.compile(self, sig)
#     883     return existing.entry_point
#     884 # Try to load from disk cache
# --> 885 cres = self._cache.load_overload(sig, self.targetctx)
#     886 if cres is not None:
#     887     self._cache_hits[sig] += 1
#
# File d:\Users\elise\OneDrive\Рабочий стол\Учёба\Магистратура\2 триместр\Регрессионный анализ\.venv\lib\site-packages\numba\core\caching.py:681, in Cache.load_overload(self, sig, target_context)
#     679 target_context.refresh()
#     680 with self._guard_against_spurious_io_errors():
# --> 681     return self._load_overload(sig, target_context)
#
# File d:\Users\elise\OneDrive\Рабочий стол\Учёба\Магистратура\2 триместр\Регрессионный анализ\.venv\lib\site-packages\numba\core\caching.py:690, in Cache._load_overload(self, sig, target_context)
#     688 data = self._cache_file.load(key)
#     689 if data is not None:
# --> 690     data = self._impl.rebuild(target_context, data)
#     691 return data
#
# File d:\Users\elise\OneDrive\Рабочий стол\Учёба\Магистратура\2 триместр\Регрессионный анализ\.venv\lib\site-packages\numba\core\caching.py:441, in CompileResultCacheImpl.rebuild(self, target_context, payload)
#     437 def rebuild(self, target_context, payload):
#     438     """
#     439     Returns the unserialized CompileResult
#     440     """
# --> 441     return compiler.CompileResult._rebuild(target_context, *payload)
#
# File d:\Users\elise\OneDrive\Рабочий стол\Учёба\Магистратура\2 триместр\Регрессионный анализ\.venv\lib\site-packages\numba\core\compiler.py:236, in CompileResult._rebuild(cls, target_context, libdata, fndesc, env, signature, objectmode, lifted, typeann, reload_init, referenced_envs)
#     233     for fn in reload_init:
#     234         fn()
# --> 236 library = target_context.codegen().unserialize_library(libdata)
#     237 cfunc = target_context.get_executable(library, fndesc, env)
#     238 cr = cls(target_context=target_context,
#     239          typing_context=target_context.typing_context,
#     240          library=library,
#    (...)
#     252          referenced_envs=referenced_envs,
#     253          )
#
# File d:\Users\elise\OneDrive\Рабочий стол\Учёба\Магистратура\2 триместр\Регрессионный анализ\.venv\lib\site-packages\numba\core\codegen.py:1166, in Codegen.unserialize_library(self, serialized)
#    1165 def unserialize_library(self, serialized):
# -> 1166     return self._library_class._unserialize(self, serialized)
#
# File d:\Users\elise\OneDrive\Рабочий стол\Учёба\Магистратура\2 триместр\Регрессионный анализ\.venv\lib\site-packages\numba\core\codegen.py:947, in CPUCodeLibrary._unserialize(cls, codegen, state)
#     945 self.enable_object_caching()
#     946 self._set_compiled_object(object_code)
# --> 947 self._shared_module = ll.parse_bitcode(shared_bitcode)
#     948 self._finalize_final_module()
#     949 # Load symbols from cache
#
# File d:\Users\elise\OneDrive\Рабочий стол\Учёба\Магистратура\2 триместр\Регрессионный анализ\.venv\lib\site-packages\llvmlite\binding\module.py:38, in parse_bitcode(bitcode, context)
#      36 bufsize = len(bitcode)
#      37 with ffi.OutputString() as errmsg:
# ---> 38     mod = ModuleRef(ffi.lib.LLVMPY_ParseBitcode(
#      39         context, buf, bufsize, errmsg), context)
#      40     if errmsg:
#      41         mod.close()
#
# File d:\Users\elise\OneDrive\Рабочий стол\Учёба\Магистратура\2 триместр\Регрессионный анализ\.venv\lib\site-packages\llvmlite\binding\ffi.py:197, in _lib_fn_wrapper.__call__(self, *args, **kwargs)
#     195 def __call__(self, *args, **kwargs):
#     196     with self._lock:
# --> 197         return self._cfn(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# # Distance-based  Time Series Classification (TSC) <a id="classification"></a>
#
# ## Univariate Time Series
#
# Одним из первых способов классификации набора временных рядов является использование k-ближайшего
# подход соседей (kNN) в сочетании с соответствующей мерой расстояния временного ряда.
#
# Самый простой способ — использовать подход kNN «scikit-learn» в сочетании с определением расстояний.
# реализовано в `aeon`. Есть два разных способа:
#
# 1. Передайте функцию расстояния как вызываемую для параметра «метрика» в конструкторе.
#
# или
#
# 2. Установите в конструкторе для метрики значение «предварительно вычисленное» и передайте попарное расстояние.
# матрица для «подгонки» и «предсказания».
#
#
#
# В этом примере мы загружаем набор данных о прицеле, используя двумерный массив numpy, который имеет два размера (n_cases, n_timepoints), учитывая, что это принятый формат `scikit-learn`.
# Несмотря на то, что `aeon` позволяет использовать 2D-массивы, обычно предпочитает 3D-массивы в форма (n_cases, n_channels, n_timepoints).

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier(n_neighbors=3, metric=dtw_distance)
knn.fit(X_train_utsc, y_train_utsc)
predictions_utsc = knn.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, predictions_utsc)
print(f"Accuracy of 1-NN (sklearn) with DTW is {accuracy}")
# Out:
# Accuracy of 1-NN (sklearn) with DTW is 0.575

# %%
from aeon.classification.distance_based import KNeighborsTimeSeriesClassifier

knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=3, distance=dtw_distance)
knn_aeon.fit(X_train_utsc, y_train_utsc)
predictions_utsc_aeon = knn_aeon.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, predictions_utsc_aeon)
print(f"Accuracy of 1-NN (aeon) with DTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with DTW is 0.55

# %% [markdown]
# ## Distance-based Multivariate TSC (MTSC)
#
#
# Версия scikit-learn kNN не может быть применена к трехмерным массивам numpy. Однако, как мы только что видели, существует способ, которым расстояния временных рядов могут быть связаны с scikit-learn kNN: использование заранее вычисленных парных расстояний (в данном случае с расстоянием ADTW, чтобы показать разнообразие расстояний, включенных в `aeon`):

# %%
from aeon.distances import adtw_pairwise_distance, adtw_distance


train_dists = adtw_pairwise_distance(X_train_mtsc)
test_dists = adtw_pairwise_distance(X_test_mtsc, X_train_mtsc)

# scikit-learn KNN classifier with precomputed distances
knn = KNeighborsClassifier(metric="precomputed", n_neighbors=1)
knn.fit(train_dists, y_train_mtsc)
predictions_mtsc = knn.predict(test_dists)

print(
    f"Accuracy of 1-NN (sklearn) with ADTW using precomputed distances is",
    f"{accuracy_score(y_test_mtsc, predictions_mtsc)}"
)
# Out:
# Accuracy of 1-NN (sklearn) with ADTW using precomputed distances is 0.525

# %% [markdown]
# Теперь, если мы запустим подход kNN, специфичный для временных рядов, включенный в `aeon`, нам не нужно предварительно вычислять матрицу попарных расстояний, которая иногда может требовать больших вычислительных ресурсов и памяти.
#
# Для тех расстояний, которые уже реализованы в `aeon`, мы можем использовать их идентификатор вместо вызываемого расстояния. Например, расстояние ADTW обозначается как `adtw`.

# %%
knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=1, distance=adtw_distance)
knn_aeon.fit(X_train_mtsc, y_train_mtsc)
predictions_mtsc_aeon = knn_aeon.predict(X_test_mtsc)

accuracy = accuracy_score(y_test_mtsc, predictions_mtsc_aeon)
print(f"Accuracy of 1-NN (aeon) with ADTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with ADTW is 0.525

# %%
knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=1, distance="adtw")
knn_aeon.fit(X_train_mtsc, y_train_mtsc)
predictions_mtsc_aeon = knn_aeon.predict(X_test_mtsc)

accuracy = accuracy_score(y_test_mtsc, predictions_mtsc_aeon)
print(f"Accuracy of 1-NN (aeon) with ADTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with ADTW is 0.525

# %% [markdown]
# # Distance-based  Time Series Extrinsic Regression <a id='regres'></a>
#
# ## Univariate Time Series Extrinsic Regression (TSER)
#
# Рассмотрим два подхода к регрессии на основе двух метрик расстояния MSM и TWE.

# %%
from aeon.distances import (
    msm_pairwise_distance,
    twe_pairwise_distance,
)
from aeon.regression.distance_based import KNeighborsTimeSeriesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

train_dists = msm_pairwise_distance(X_train_utser)
test_dists = msm_pairwise_distance(X_test_utser, X_train_utser)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_utser)
predictions_utser = knn.predict(test_dists)

mse = mean_squared_error(y_test_utser, predictions_utser)
print(f"MSE of 1-NN (sklearn) with MSM is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(n_neighbors=1, distance="msm")
knn_aeon.fit(X_train_utser, y_train_utser)
predictions_utser_aeon = knn_aeon.predict(X_test_utser)

mse = mean_squared_error(y_test_utser, predictions_utser_aeon)
print(f"MSE of 1-NN (aeon) with MSM is {mse}")
# Out:
# MSE of 1-NN (sklearn) with MSM is 1.3942060469112671
# MSE of 1-NN (aeon) with MSM is 1.3942060469112671

# %%
# Now, for the TWE distance:
train_dists = twe_pairwise_distance(X_train_utser, window=0.1)
test_dists = twe_pairwise_distance(X_test_utser, X_train_utser, window=0.1)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_utser)
predictions_utser = knn.predict(test_dists)

mse = mean_squared_error(y_test_utser, predictions_utser)
print(f"MSE of 1-NN (sklearn) with TWE is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(
    n_neighbors=1,
    distance="twe",
    distance_params={"window": 0.1}
)
knn_aeon.fit(X_train_utser, y_train_utser)
predictions_utser_aeon = knn_aeon.predict(X_test_utser)

mse = mean_squared_error(y_test_utser, predictions_utser_aeon)
print(f"MSE of 1-NN (aeon) with TWE is {mse}")
# Out:
# MSE of 1-NN (sklearn) with TWE is 1.7049822984745453
# MSE of 1-NN (aeon) with TWE is 1.7049822984745453

# %% [markdown]
# ## Distance-based Multivariate TSER (MTSER)

# %%
from aeon.distances import (
    erp_pairwise_distance,
    wdtw_pairwise_distance,
)
from aeon.regression.distance_based import KNeighborsTimeSeriesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error


train_dists = erp_pairwise_distance(X_train_mtser)
test_dists = erp_pairwise_distance(X_test_mtser, X_train_mtser)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_mtser)
predictions_mtser = knn.predict(test_dists)

mse = mean_squared_error(y_test_mtser, predictions_mtser)
print(f"MSE of 1-NN (sklearn) with ERP is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(n_neighbors=1, distance="erp")
knn_aeon.fit(X_train_mtser, y_train_mtser)
predictions_mtser_aeon = knn_aeon.predict(X_test_mtser)

mse = mean_squared_error(y_test_mtser, predictions_mtser_aeon)
print(f"MSE of 1-NN (aeon) with ERP is {mse}")
# Out:
# MSE of 1-NN (sklearn) with ERP is 1.0155583588945694
# MSE of 1-NN (aeon) with ERP is 1.0155583588945694

# %%
# Now, for the wdtw distance:
train_dists = wdtw_pairwise_distance(X_train_mtser, window=0.1)
test_dists = wdtw_pairwise_distance(X_test_mtser, X_train_mtser, window=0.1)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_mtser)
predictions_mtser = knn.predict(test_dists)

mse = mean_squared_error(y_test_mtser, predictions_mtser)
print(f"MSE of 1-NN (sklearn) with WDTW is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(
    n_neighbors=1,
    distance="wdtw",
    distance_params={"window": 0.1}
)
knn_aeon.fit(X_train_mtser, y_train_mtser)
predictions_mtser_aeon = knn_aeon.predict(X_test_mtser)

mse = mean_squared_error(y_test_mtser, predictions_mtser_aeon)
print(f"MSE of 1-NN (aeon) with WDTW is {mse}")
# Out:
# MSE of 1-NN (sklearn) with WDTW is 1.3909486821400647
# MSE of 1-NN (aeon) with WDTW is 1.3909486821400647

# %% [markdown]
# ## Elastic Ensemble (EE) и Proximity Forest (PF)
#
# Другими более продвинутыми подходами являются EE и PF.
#
# EE представляет собой взвешенный ансамбль из 11 классификаторов 1-NN с рядом эластичных мер расстояния. Это требует перекрестной проверки весов каждого классификатора в ансамбле.
#
# В случае PF алгоритм представляет собой ансамбль высокорандомизированных деревьев близости, которые разветвляются по близости временных рядов к тому или иному образцовому временному ряду, а не по значениям атрибутов.

# %%
from aeon.classification.distance_based import ElasticEnsemble

ee = ElasticEnsemble(
    proportion_of_param_options=0.1,
    proportion_train_in_param_finding=0.3,
    proportion_train_for_test=0.5,
)
ee.fit(X_train_utsc, y_train_utsc)
ee_preds = ee.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, ee_preds)
print(f"Accuracy of Elastic Ensemble is {accuracy}.")
# Out:
# Accuracy of Elastic Ensemble is 0.5.

# %% [markdown]
# Более конкретно, реализация EE в `aeon` позволяет выбирать заданные меры расстояния для построения ансамбля, а также изменять некоторые параметры процедуры перекрестной проверки:

# %%
ee = ElasticEnsemble(
    distance_measures=["dtw", "msm"],
    proportion_of_param_options=0.1,
    proportion_train_in_param_finding=0.3,
    proportion_train_for_test=0.5,
)
ee.fit(X_train_utsc, y_train_utsc)
ee_preds = ee.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, ee_preds)
print(f"Accuracy of Elastic Ensemble with DTW and MSM is {accuracy}.")
# Out:
# Accuracy of Elastic Ensemble with DTW and MSM is 0.55.

# %% [markdown]
# Подход PF недавно был включен в `aeon` и на данный момент может решать только одномерные задачи TSC:

# %%
from aeon.classification.distance_based import ProximityForest

pf = ProximityForest(n_trees=10, random_state=0)
pf.fit(X_train_utsc, y_train_utsc)
pf_preds = pf.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, pf_preds)
print(f"Accuracy of Proximity Forest is {accuracy}.")
# Out:
# Accuracy of Proximity Forest is 0.525.

# %% [markdown]
# # Подходы, основанные на свертках <a id='conv'></a>
#
# ### Rocket
#
# RocketClassifier()
# Rocket — оригинальный сверточный метод классификации временных рядов.
#
# ### MiniRocket
# RocketClassifier(rocket_transform = "minirocket") — модификация Rocket, более точная.
#
# ###  Hydra
# HydraClassifier()
# HydraRegressor()
#
# Hydra — это вариант Rocket, который объединяет функции и методы подходов на основе словаря.
#
# Примечание. Гидра реализована с использованием torch. Для запуска этого кода вам понадобится установить его.
# pip install torch.
#
#
# ###  MultiRocket+Hydra
# MultiRocketHydraClassifier()
# MultiRocket+Hydra сочетает в себе подходы MultiRocket и Hydra.

# %%
from aeon.classification.convolution_based import RocketClassifier

classifier = RocketClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.425

# %%
from aeon.classification.convolution_based import MiniRocketClassifier

classifier = MiniRocketClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.9

# %%
from aeon.classification.convolution_based import  HydraClassifier

classifier = HydraClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.925

# %%
from aeon.classification.convolution_based import  MultiRocketHydraClassifier

classifier = MultiRocketHydraClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.875

# %%
from aeon.regression.convolution_based import MiniRocketRegressor
from sklearn.metrics import r2_score

regressor = MiniRocketRegressor(n_jobs=-1, random_state=42)
regressor.fit(X_train_mtser, y_train_mtser)
preds = regressor.predict(X_test_mtser)
r2_score(y_test_mtser, preds)
# Out:
# 0.4110569698148919

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, preds)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: xlabel='Actual values', ylabel='Predicted values'>)

# %%
# FineTuning parameters 

from sklearn.model_selection import GridSearchCV
import numpy as np
import matplotlib.pyplot as plt
from aeon.regression.convolution_based import MiniRocketRegressor

# ==============================================================================
# == fit =======================================================================
# ==============================================================================

param_grid = {
    "n_kernels" : [100, 1000, 10000],
    "max_dilations_per_kernel" : [16, 32, 64],
}

gs = GridSearchCV(
    MiniRocketRegressor(n_jobs=-1, random_state=42),
    param_grid,
)
gs.fit(X_train_mtser, y_train_mtser)

# ==============================================================================
# == plot results ==============================================================
# ==============================================================================

_scores = gs.cv_results_["mean_test_score"]
_params = np.array([f"d={_[0]}\nk={_[1]}" for _ in [tuple(_.values()) for _ in gs.cv_results_["params"]]])
_order = _scores.argsort()
_, a = plt.subplots(1, 1, figsize = (6, 4))
a.plot(_params[_order], _scores[_order], ".-")
a.set(xlabel = "d/k", ylabel = "r2")
plt.show()

# %%
# считаем скор для лучшей конфигурации
gs.score(X_test_mtser, y_test_mtser)
# Out:
# 0.39129226372986503

# %%
# смотри лучший набор

gs
# Out:
# GridSearchCV(estimator=MiniRocketRegressor(n_jobs=-1, random_state=42),
#              param_grid={'max_dilations_per_kernel': [16, 32, 64],
#                          'n_kernels': [100, 1000, 10000]})

# %% [markdown]
# # Feature based classification and regression <a id='feature'></a>
#
# Классификаторы и регрессоры на основе признаков являются популярной темой в классификации временных рядов (TSC) и регрессии (TSER).  В пригципе все такие модели представляют собой пайплайны из вытаскивателей фич и классификаторов/регрессоров.
#
# <img src="data/aeon/pipeline.png" alt="Pipeline classifier."><img>

# %%
# отрисуем наши данные 

from aeon.visualisation import plot_collection_by_class

plot_collection_by_class(X_train_mtsc[:,2,:], y_train_mtsc)
# Out:
# (<Figure size 1200x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
from matplotlib import pyplot as plt

plt.plot(X_train_mtser[0].T)
plt.legend(["Dim 0", "Dim 1", "Dim 2", "Dim 3"])

# %% [markdown]
# ## Catch22 <a id='catch22'></a>
#
# Набор инструментов для сравнительного анализа временных рядов (hctsa) может создать более 7700 функций для исследовательского анализа временных рядов. К сожалению, в настоящее время в Python не существует полного набора этих функций, заинтересованные пользователи могут ознакомиться с соответствующей публикацией и исходным набором инструментов MATLAB.
#
# Канонические характеристики временных рядов (Catch22) представляют собой 22 характеристики hctsa, которые считаются наиболее дискриминационными из полного набора.
#
# Функции Catch22 были выбраны путем оценки наборов данных UCR. Характеристики hctsa изначально были сокращены: были удалены те, которые чувствительны к среднему значению и дисперсии, а также те, которые невозможно вычислить для более чем 80 % наборов данных UCR. Затем была проведена оценка функций на основе прогнозируемой производительности. Любые функции, производительность которых была ниже порогового значения, были удалены. Для остальных признаков была выполнена иерархическая кластеризация корреляционной матрицы для устранения избыточности. Из каждого из 22 сформированных кластеров был выбран один признак с учетом сбалансированной точности, вычислительной эффективности и интерпретируемости. Функции Catch22 охватывают широкий спектр понятий, таких как базовая статистика значений рядов данных, линейные корреляции и энтропия.
#
#
# <img src="data/aeon/catch22.png" alt="Catch22 extraction process."></img>

# %% [markdown]
# Класс Catch22 преобразует временные ряды в 22 признака.

# %%
from aeon.transformations.collection.feature_based import Catch22


c22 = Catch22()
c22.fit_transform(X_train_mtsc)[:5]
# Out:
# array([[-4.94433107e-06,  6.92507633e-06,  2.98422388e+00,
#          4.00000000e+00, -8.88178420e-16, -1.01000518e-15,
#          0.00000000e+00,  1.60000000e+01,  1.11111111e-01,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          3.84615385e-02, -2.70000000e-01,  5.30000000e-01,
#          1.57359203e-10,  5.00000000e+00,  2.00785293e+00,
#          8.28571429e-01,  6.00000000e-01,  4.90873852e-01,
#          1.40193684e-05,  1.81815758e-06, -1.47671393e-06,
#          3.71562980e+00,  4.00000000e+00, -8.88178420e-16,
#         -5.87837340e-16,  0.00000000e+00,  1.70000000e+01,
#          6.25000000e-02,  0.00000000e+00,  0.00000000e+00,
#          3.00000000e+00,  4.54545455e-02, -2.30000000e-01,
#          4.90000000e-01,  7.77998115e-11,  7.00000000e+00,
#          2.00199666e+00,  8.28571429e-01,  8.28571429e-01,
#          2.94524311e-01,  1.02667064e-05, -6.81925616e-06,
#         -2.74171769e-06,  2.54465362e+00,  5.00000000e+00,
#         -8.88178420e-16, -4.07928862e-16,  0.00000000e+00,
#          1.20000000e+01,  4.00000000e-02,  0.00000000e+00,
#          0.00000000e+00,  4.00000000e+00,  5.26315789e-02,
#         -2.00000000e-01,  8.20000000e-01,  1.04053400e-10,
#          8.00000000e+00,  1.84997494e+00,  8.28571429e-01,
#          8.28571429e-01,  4.41786467e-01,  1.08579400e-05,
#         -4.28629432e-06, -2.09537733e-06,  2.25468230e+00,
#          5.00000000e+00, -8.88178420e-16, -1.96296224e-17,
#          0.00000000e+00,  1.30000000e+01,  6.36574074e-03,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          2.50000000e-01, -9.00000000e-02,  8.00000000e-01,
#          3.78824191e-11,  5.00000000e+00,  1.94369228e+00,
#          1.71428571e-01,  8.00000000e-01,  5.39961237e-01,
#          7.16263022e-06],
#        [-4.93347026e-07, -4.41079953e-06,  9.76550866e-01,
#          5.00000000e+00, -8.88178420e-16, -1.93131216e-15,
#          0.00000000e+00,  1.00000000e+01,  1.47737765e-02,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          2.00000000e-01, -6.00000000e-02, -5.60000000e-01,
#          1.02981595e-10,  6.00000000e+00,  2.08655852e+00,
#          1.71428571e-01,  8.28571429e-01,  7.36310778e-01,
#          1.60656562e-05,  1.06128379e-06,  4.37068609e-06,
#          2.99539703e+00,  1.00000000e+00, -8.88178420e-16,
#          2.19729828e-16,  0.00000000e+00,  1.50000000e+01,
#          2.08333333e-02,  0.00000000e+00,  0.00000000e+00,
#          2.00000000e+00,  8.33333333e-02,  9.00000000e-02,
#         -8.80000000e-01,  8.84485984e-11,  5.00000000e+00,
#          2.05946536e+00,  6.00000000e-01,  3.14285714e-01,
#          2.94524311e-01,  9.62091285e-06, -9.48719145e-06,
#         -5.45880569e-06,  1.78980033e+00,  5.00000000e+00,
#         -8.88178420e-16,  5.16491517e-17,  0.00000000e+00,
#          1.20000000e+01,  6.12182430e-03,  0.00000000e+00,
#          0.00000000e+00,  2.00000000e+00,  6.66666667e-01,
#         -3.00000000e-01, -7.40000000e-01,  7.71939551e-11,
#          6.00000000e+00,  1.96831980e+00,  1.71428571e-01,
#          7.14285714e-01,  6.87223393e-01,  1.48956808e-05,
#         -2.88989693e-06, -4.87479978e-06,  2.21747187e+00,
#          5.00000000e+00, -8.88178420e-16,  7.57005863e-17,
#          0.00000000e+00,  1.20000000e+01,  9.23361034e-03,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          2.00000000e-01, -3.00000000e-02, -7.50000000e-01,
#          3.72808238e-11,  4.00000000e+00,  2.04733206e+00,
#          1.71428571e-01,  6.85714286e-01,  4.41786467e-01,
#          7.52540169e-06],
#        [-6.72778723e-06,  2.23202708e-06,  8.30813700e-01,
#          1.00000000e+00, -8.88178420e-16,  1.16234122e-15,
#          0.00000000e+00,  1.10000000e+01,  1.73611111e-02,
#          0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          2.50000000e-01, -3.20000000e-01,  3.40000000e-01,
#          6.56303902e-11,  7.00000000e+00,  2.17460531e+00,
#          7.14285714e-01,  1.71428571e-01,  8.34485549e-01,
#          1.45365247e-05, -1.44995057e-06,  1.93312705e-06,
#          7.17005807e-01,  1.00000000e+00, -8.88178420e-16,
#         -8.69151397e-16,  0.00000000e+00,  1.20000000e+01,
#          4.62962963e-03,  0.00000000e+00,  0.00000000e+00,
#          2.00000000e+00,  1.25000000e-01, -6.00000000e-02,
#          3.20000000e-01,  3.23868358e-11,  4.00000000e+00,
#          2.16552480e+00,  8.00000000e-01,  8.00000000e-01,
#          1.32535940e+00,  1.07278852e-05, -1.83019499e-06,
#          7.62620939e-06,  2.41674894e+00,  5.00000000e+00,
#         -8.88178420e-16,  2.01394617e-16,  0.00000000e+00,
#          2.50000000e+01,  9.23361034e-03,  0.00000000e+00,
#          0.00000000e+00,  5.00000000e+00,  4.00000000e-01,
#         -2.70000000e-01, -3.80000000e-01,  9.72031604e-11,
#          6.00000000e+00,  1.94369228e+00,  8.00000000e-01,
#          7.42857143e-01,  4.41786467e-01,  1.12686720e-05,
#         -3.71330823e-06, -1.98429828e-06,  2.58492491e+00,
#          5.00000000e+00, -8.88178420e-16,  5.66426479e-17,
#          0.00000000e+00,  2.30000000e+01,  8.00000000e-02,
#          0.00000000e+00,  0.00000000e+00,  4.00000000e+00,
#          5.55555556e-02, -3.00000000e-02,  5.60000000e-01,
#          4.52016486e-11,  5.00000000e+00,  1.97770999e+00,
#          7.14285714e-01,  8.28571429e-01,  4.41786467e-01,
#          7.43561030e-06],
#        [ 1.06707589e-06,  5.06165512e-06,  9.40987016e-01,
#          4.00000000e+00, -8.88178420e-16, -1.18293308e-15,
#          0.00000000e+00,  1.20000000e+01,  1.23456790e-02,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          1.00000000e-01, -4.20000000e-01, -2.40000000e-01,
#          8.22614633e-11,  6.00000000e+00,  2.16264604e+00,
#          8.28571429e-01,  3.42857143e-01,  7.36310778e-01,
#          1.43699941e-05, -1.24257183e-06,  1.42709096e-06,
#          2.94247757e+00,  3.00000000e+00, -8.88178420e-16,
#         -2.50000611e-16,  0.00000000e+00,  1.50000000e+01,
#          4.62962963e-03,  0.00000000e+00,  0.00000000e+00,
#          2.00000000e+00,  1.25000000e-01,  2.20000000e-01,
#         -1.10000000e-01,  6.93500440e-11,  5.00000000e+00,
#          1.92542785e+00,  8.28571429e-01,  8.28571429e-01,
#          2.94524311e-01,  8.91888264e-06, -4.34236854e-06,
#         -1.88361756e-06,  2.63896118e+00,  4.00000000e+00,
#         -8.88178420e-16, -5.92485890e-16,  0.00000000e+00,
#          1.50000000e+01,  2.20385675e-02,  0.00000000e+00,
#          0.00000000e+00,  3.00000000e+00,  1.11111111e-01,
#          2.90000000e-01, -2.50000000e-01,  6.96738164e-11,
#          6.00000000e+00,  2.00650422e+00,  8.28571429e-01,
#          8.28571429e-01,  3.43611696e-01,  9.74783003e-06,
#         -3.57222777e-06, -5.38267251e-06,  3.04652712e+00,
#          1.10000000e+01, -8.88178420e-16,  4.38125672e-17,
#          0.00000000e+00,  1.40000000e+01,  5.10204082e-03,
#          0.00000000e+00,  0.00000000e+00,  5.00000000e+00,
#          1.42857143e-01,  2.80000000e-01, -1.40000000e-01,
#          4.00538711e-11,  7.00000000e+00,  2.04099986e+00,
#          7.71428571e-01,  2.00000000e-01,  3.43611696e-01,
#          6.30681363e-06],
#        [ 5.41709902e-06,  2.05431239e-06,  8.54785389e-01,
#          3.00000000e+00, -8.88178420e-16, -1.76750953e-15,
#          0.00000000e+00,  1.00000000e+01,  3.67309458e-03,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          3.33333333e-01,  2.08166817e-17, -6.20000000e-01,
#          5.81324313e-11,  5.00000000e+00,  2.15525567e+00,
#          7.71428571e-01,  3.71428571e-01,  1.07992247e+00,
#          1.58005635e-05, -5.96238663e-07,  2.76329744e-06,
#          7.96695469e-01,  2.00000000e+00, -8.88178420e-16,
#         -5.99472331e-16,  0.00000000e+00,  9.00000000e+00,
#          1.93905817e-02,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  2.00000000e-01, -2.00000000e-02,
#         -5.50000000e-01,  3.29836877e-11,  5.00000000e+00,
#          2.14756047e+00,  8.00000000e-01,  8.28571429e-01,
#          1.27627202e+00,  1.12504263e-05,  5.73291371e-06,
#          2.48495087e-06,  1.59802527e+00,  4.00000000e+00,
#         -8.88178420e-16, -5.00682720e-16,  0.00000000e+00,
#          8.00000000e+00,  3.36700337e-03,  0.00000000e+00,
#          0.00000000e+00,  2.00000000e+00,  3.33333333e-01,
#         -1.90000000e-01,  6.90000000e-01,  4.75743565e-11,
#          6.00000000e+00,  2.11236435e+00,  1.71428571e-01,
#          8.28571429e-01,  6.38136008e-01,  1.26219064e-05,
#         -1.88620306e-07,  1.45344422e-06,  1.46937513e+00,
#          5.00000000e+00, -8.88178420e-16, -3.32636878e-17,
#          0.00000000e+00,  1.70000000e+01,  5.20355066e-03,
#          0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          3.33333333e-01,  8.00000000e-02, -1.50000000e-01,
#          2.18684364e-11,  5.00000000e+00,  2.03344937e+00,
#          1.71428571e-01,  8.28571429e-01,  6.38136008e-01,
#          7.81002358e-06]])

# %%
from aeon.transformations.collection.feature_based._catch22 import feature_names

feature_names
# Out:
# ['DN_HistogramMode_5',
#  'DN_HistogramMode_10',
#  'CO_f1ecac',
#  'CO_FirstMin_ac',
#  'CO_HistogramAMI_even_2_5',
#  'CO_trev_1_num',
#  'MD_hrv_classic_pnn40',
#  'SB_BinaryStats_mean_longstretch1',
#  'SB_TransitionMatrix_3ac_sumdiagcov',
#  'PD_PeriodicityWang_th0_01',
#  'CO_Embed2_Dist_tau_d_expfit_meandiff',
#  'IN_AutoMutualInfoStats_40_gaussian_fmmi',
#  'FC_LocalSimple_mean1_tauresrat',
#  'DN_OutlierInclude_p_001_mdrmd',
#  'DN_OutlierInclude_n_001_mdrmd',
#  'SP_Summaries_welch_rect_area_5_1',
#  'SB_BinaryStats_diff_longstretch0',
#  'SB_MotifThree_quantile_hh',
#  'SC_FluctAnal_2_rsrangefit_50_1_logi_prop_r1',
#  'SC_FluctAnal_2_dfa_50_1_2_logi_prop_r1',
#  'SP_Summaries_welch_rect_centroid',
#  'FC_LocalSimple_mean3_stderr']

# %% [markdown]
# Преобразование можно настроить, и вы можете выбрать подмножество функций для извлечения. Параметр catch24 будет включать среднее и стандартное отклонение, а также исходные 22 функции.
#
# pycatch22 будет использовать библиотеку pycatch22, завернутую в C.

# %%
c22 = Catch22(
    features=["DN_HistogramMode_5", "CO_f1ecac", "SB_MotifThree_quantile_hh", "Mean", "StandardDeviation"],
    catch24=True,
)
c22.fit_transform(X_train_mtsc)[:5]
# Out:
# array([[-4.94433107e-06,  2.98422388e+00,  2.00785293e+00,
#         -4.84662295e-06,  1.63624369e-05,  1.81815758e-06,
#          3.71562980e+00,  2.00199666e+00,  4.07268745e-07,
#          1.16629572e-05, -6.81925616e-06,  2.54465362e+00,
#          1.84997494e+00, -2.73869572e-06,  1.30628441e-05,
#         -4.28629432e-06,  2.25468230e+00,  1.94369228e+00,
#         -3.51260400e-06,  8.11090668e-06],
#        [-4.93347026e-07,  9.76550866e-01,  2.08655852e+00,
#          1.43118551e-06,  1.57514418e-05,  1.06128379e-06,
#          2.99539703e+00,  2.05946536e+00,  4.93131265e-06,
#          1.18989896e-05, -9.48719145e-06,  1.78980033e+00,
#          1.96831980e+00, -3.01206374e-06,  1.42330289e-05,
#         -2.88989693e-06,  2.21747187e+00,  2.04733206e+00,
#         -2.96546855e-06,  8.23176010e-06],
#        [-6.72778723e-06,  8.30813700e-01,  2.17460531e+00,
#         -6.06350354e-07,  1.33059491e-05, -1.44995057e-06,
#          7.17005807e-01,  2.16552480e+00,  3.79695308e-06,
#          1.00766877e-05, -1.83019499e-06,  2.41674894e+00,
#          1.94369228e+00,  3.37033758e-06,  1.24823971e-05,
#         -3.71330823e-06,  2.58492491e+00,  1.97770999e+00,
#          8.40880283e-07,  8.31148145e-06],
#        [ 1.06707589e-06,  9.40987016e-01,  2.16264604e+00,
#         -2.17892949e-07,  1.41719989e-05, -1.24257183e-06,
#          2.94247757e+00,  1.92542785e+00, -2.02235649e-06,
#          1.04135837e-05, -4.34236854e-06,  2.63896118e+00,
#          2.00650422e+00, -2.30261793e-06,  1.08641355e-05,
#         -3.57222777e-06,  3.04652712e+00,  2.04099986e+00,
#         -2.96036604e-06,  7.47429838e-06],
#        [ 5.41709902e-06,  8.54785389e-01,  2.15525567e+00,
#          3.07705341e-06,  1.41351503e-05, -5.96238663e-07,
#          7.96695469e-01,  2.14756047e+00,  8.81621473e-09,
#          1.01270483e-05,  5.73291371e-06,  1.59802527e+00,
#          2.11236435e+00,  2.83706608e-06,  1.17155555e-05,
#         -1.88620306e-07,  1.46937513e+00,  2.03344937e+00,
#         -8.22774051e-07,  7.29112178e-06]])

# %% [markdown]
# Классы Catch22Classifier и Catch22Regressor в aeon — это просто удобные оболочки для конвейера преобразования Catch22 и случайного леса, обучаемого scikit-learn по умолчанию.

# %%
from aeon.classification.feature_based import Catch22Classifier
from sklearn.metrics import accuracy_score

c22_cls = Catch22Classifier(random_state=42)
c22_cls.fit(X_train_mtsc, y_train_mtsc)
c22_preds_c = c22_cls.predict(X_test_mtsc)
accuracy_score(y_test_mtsc, c22_preds_c)
# Out:
# 0.9

# %%
from aeon.classification.sklearn import RotationForestClassifier

c22_cls = Catch22Classifier(
    features=["DN_HistogramMode_5", "CO_f1ecac", "SB_MotifThree_quantile_hh", "Mean", "StandardDeviation"],
    estimator=RotationForestClassifier(),
    random_state=42,
)
c22_cls.fit(X_train_mtsc, y_train_mtsc)
c22_preds_c = c22_cls.predict(X_test_mtsc)
accuracy_score(y_test_mtsc, c22_preds_c)
# Out:
# 0.9

# %%
from aeon.regression.feature_based import Catch22Regressor
from sklearn.metrics import mean_squared_error

c22_reg = Catch22Regressor(random_state=42)
c22_reg.fit(X_train_mtser, y_train_mtser)
c22_preds_r = c22_reg.predict(X_test_mtser)
mean_squared_error(y_test_mtser, c22_preds_r)
# Out:
# 0.7975235446926242

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, c22_preds_r)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: xlabel='Actual values', ylabel='Predicted values'>)

# %% [markdown]
# # Deep Leaning подходы <a id='deep'></a>
#
# Можно сказать, что на данном этапе модели глубокого обучения являются SOTA моделями для решения задач классификации и регрессии временных рядов.
#
#
# <img src="data/aeon/deep-legend.png" alt="Deep Legend."></img>

# %%
# Для классификации
# нормализуем по среднему и дисперсии наши ряды 
X_train_c = (X_train_mtsc - X_train_mtsc.mean(axis=-1, keepdims=True)) / (X_train_mtsc.std(axis=-1, keepdims=True))
X_test_c = (X_test_mtsc - X_test_mtsc.mean(axis=-1, keepdims=True)) / (X_test_mtsc.std(axis=-1, keepdims=True))

print("Train shape:", X_train_c.shape)
print("Test shape:", X_test_c.shape)
# Out:
# Train shape: (40, 4, 100)
# Test shape: (40, 4, 100)

# %%
from aeon.visualisation import plot_collection_by_class

plot_collection_by_class(X_train_c[:,0,:], y_train_mtsc)
# Out:
# (<Figure size 1200x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
# для регрессии

# znormalize the series
X_train_r = (X_train_mtser - X_train_mtser.mean(axis=-1, keepdims=True)) / (X_train_mtser.std(axis=-1, keepdims=True))
X_test_r = (X_test_mtser - X_test_mtser.mean(axis=-1, keepdims=True)) / (X_test_mtser.std(axis=-1, keepdims=True))

print("Train shape:", X_train_mtser.shape)
print("Test shape:", X_test_mtser.shape)
# Out:
# Train shape: (72, 4, 100)
# Test shape: (72, 4, 100)

# %%
from matplotlib import pyplot as plt

plt.plot(X_train_r[:5,0,:].T)
plt.title("EEG Regression Samples")
plt.xlabel("Time")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ## Multi Layer Perceptron (MLP)
#
#
# Многослойный персептрон (MLP), простейшая модель нейронных сетей, часто используется в качестве основы для моделей глубокого обучения. Однако применительно к данным временных рядов он не учитывает временные зависимости. Модель MLP пытается найти оптимальную нелинейную комбинацию входных функций для достижения хорошей производительности последующей задачи.
#
# <img src="data/aeon/MLP.png" alt="mlp"><i>

# %%
from aeon.classification.deep_learning import MLPClassifier
from sklearn.metrics import accuracy_score

mlp_cls = MLPClassifier(n_epochs=100)
mlp_cls.fit(X_train_c, y_train_mtsc)
mlp_cls_preds = mlp_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, mlp_cls_preds))
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 0.525

# %%
from aeon.regression.deep_learning import MLPRegressor
from sklearn.metrics import mean_squared_error

mlp_rgs = MLPRegressor(n_epochs=500)
mlp_rgs.fit(X_train_r, y_train_mtser)
mlp_rgs_preds = mlp_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, mlp_rgs_preds))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1.6786025653900205

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, mlp_rgs_preds, title="MLP Predictions")
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'MLP Predictions'}, xlabel='Actual values', ylabel='Predicted values'>)

# %% [markdown]
# ## The Fully Convolutional Neural Network (FCNRegressor)
#
#
# Полностью сверточные нейронные сети (FCN) все чаще используются для анализа временных рядов благодаря их способности эффективно улавливать локальные закономерности и многомасштабные зависимости.
#
# Сверточная нейронная сеть по времени (TimeCNN) — это сверточная нейронная сеть, в которой процесс оптимизации фокусируется на изучении наиболее эффективных фильтров для достижения оптимальных результатов. В отличие от MLP, TimeCNN использует локальные свертки, позволяя улавливать и учитывать временные зависимости в данных, что делает их более подходящими для анализа временных рядов.
#
# <img src="data/aeon/TimeCNN.png" alt="cnn"><i>

# %%
from aeon.classification.deep_learning import FCNClassifier
from sklearn.metrics import accuracy_score

# n_epochs chooses the number of training iterations
# verbose show the network's detail and the logs of training
cnn_cls = FCNClassifier(n_epochs=500, verbose=True, save_best_model=True, best_file_name="best_cnn")
cnn_cls.fit(X_train_c, y_train_mtsc)
cnn_cls_preds = cnn_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, cnn_cls_preds))
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 100, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 100, 128)       │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 100, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 100, 256)       │       164,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 100, 128)       │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 100, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 269,058 (1.03 MB)
#  Trainable params: 268,034 (1.02 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6250 - loss: 0.5762 - learning_rate: 0.0010
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9500 - loss: 0.1944 - learning_rate: 0.0010
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1017 - learning_rate: 0.0010
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0606 - learning_rate: 0.0010
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0409 - learning_rate: 0.0010
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0297 - learning_rate: 0.0010
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0231 - learning_rate: 0.0010
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0188 - learning_rate: 0.0010
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0157 - learning_rate: 0.0010
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0133 - learning_rate: 0.0010
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0115 - learning_rate: 0.0010
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0102 - learning_rate: 0.0010
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0092 - learning_rate: 0.0010
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0083 - learning_rate: 0.0010
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0076 - learning_rate: 0.0010
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0070 - learning_rate: 0.0010
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0065 - learning_rate: 0.0010
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0061 - learning_rate: 0.0010
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0057 - learning_rate: 0.0010
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0054 - learning_rate: 0.0010
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0051 - learning_rate: 0.0010
# Epoch 22/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0049 - learning_rate: 0.0010
# Epoch 23/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0046 - learning_rate: 0.0010
# Epoch 24/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0044 - learning_rate: 0.0010
# Epoch 25/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0042 - learning_rate: 0.0010
# Epoch 26/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0040 - learning_rate: 0.0010
# Epoch 27/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0039 - learning_rate: 0.0010
# Epoch 28/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0037 - learning_rate: 0.0010
# Epoch 29/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0036 - learning_rate: 0.0010
# Epoch 30/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0035 - learning_rate: 0.0010
# Epoch 31/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0033 - learning_rate: 0.0010
# Epoch 32/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0032 - learning_rate: 0.0010
# Epoch 33/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0031 - learning_rate: 0.0010
# Epoch 34/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0030 - learning_rate: 0.0010
# Epoch 35/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0029 - learning_rate: 0.0010
# Epoch 36/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0028 - learning_rate: 0.0010
# Epoch 37/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0027 - learning_rate: 0.0010
# Epoch 38/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0027 - learning_rate: 0.0010
# Epoch 39/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0026 - learning_rate: 0.0010
# Epoch 40/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0025 - learning_rate: 0.0010
# Epoch 41/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0024 - learning_rate: 0.0010
# Epoch 42/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0024 - learning_rate: 0.0010
# Epoch 43/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0023 - learning_rate: 0.0010
# Epoch 44/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0022 - learning_rate: 0.0010
# Epoch 45/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0022 - learning_rate: 0.0010
# Epoch 46/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0021 - learning_rate: 0.0010
# Epoch 47/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0021 - learning_rate: 0.0010
# Epoch 48/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0020 - learning_rate: 0.0010
# Epoch 49/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0020 - learning_rate: 0.0010
# Epoch 50/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0019 - learning_rate: 0.0010
# Epoch 51/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0019 - learning_rate: 0.0010
# Epoch 52/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0018 - learning_rate: 0.0010
# Epoch 53/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0018 - learning_rate: 0.0010
# Epoch 54/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0018 - learning_rate: 0.0010
# Epoch 55/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0017 - learning_rate: 0.0010
# Epoch 56/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0017 - learning_rate: 0.0010
# Epoch 57/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0016 - learning_rate: 0.0010
# Epoch 58/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0016 - learning_rate: 0.0010
# Epoch 59/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0016 - learning_rate: 0.0010
# Epoch 60/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 61/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 62/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 63/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 64/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 65/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 66/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 67/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 68/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 69/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 70/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 71/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 72/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 73/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 74/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 75/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 76/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 77/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 78/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 79/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 80/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 81/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 82/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0010 - learning_rate: 0.0010
# Epoch 83/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0010 - learning_rate: 0.0010
# Epoch 84/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0010 - learning_rate: 0.0010
# Epoch 85/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 9.8533e-04 - learning_rate: 0.0010
# Epoch 86/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 9.7014e-04 - learning_rate: 0.0010
# Epoch 87/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 9.5532e-04 - learning_rate: 0.0010
# Epoch 88/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 9.4088e-04 - learning_rate: 0.0010
# Epoch 89/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 9.2677e-04 - learning_rate: 0.0010
# Epoch 90/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 9.1303e-04 - learning_rate: 0.0010
# Epoch 91/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 8.9959e-04 - learning_rate: 0.0010
# Epoch 92/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 8.8649e-04 - learning_rate: 0.0010
# Epoch 93/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 8.7368e-04 - learning_rate: 0.0010
# Epoch 94/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 8.6116e-04 - learning_rate: 0.0010
# Epoch 95/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 8.4894e-04 - learning_rate: 0.0010
# Epoch 96/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 8.3700e-04 - learning_rate: 0.0010
# Epoch 97/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 8.2533e-04 - learning_rate: 0.0010
# Epoch 98/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 8.1393e-04 - learning_rate: 0.0010
# Epoch 99/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 8.0279e-04 - learning_rate: 0.0010
# Epoch 100/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 7.9190e-04 - learning_rate: 0.0010
# Epoch 101/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 7.8123e-04 - learning_rate: 0.0010
# Epoch 102/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 7.7080e-04 - learning_rate: 0.0010
# Epoch 103/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 7.6058e-04 - learning_rate: 0.0010
# Epoch 104/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 7.5058e-04 - learning_rate: 0.0010
# Epoch 105/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 7.4078e-04 - learning_rate: 0.0010
# Epoch 106/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 7.3118e-04 - learning_rate: 0.0010
# Epoch 107/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 7.2178e-04 - learning_rate: 0.0010
# Epoch 108/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 7.1259e-04 - learning_rate: 0.0010
# Epoch 109/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 7.0357e-04 - learning_rate: 0.0010
# Epoch 110/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 6.9472e-04 - learning_rate: 0.0010
# Epoch 111/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 6.8605e-04 - learning_rate: 0.0010
# Epoch 112/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 6.7755e-04 - learning_rate: 0.0010
# Epoch 113/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 6.6922e-04 - learning_rate: 0.0010
# Epoch 114/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 6.6105e-04 - learning_rate: 0.0010
# Epoch 115/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 6.5305e-04 - learning_rate: 0.0010
# Epoch 116/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 6.4520e-04 - learning_rate: 0.0010
# Epoch 117/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 6.3750e-04 - learning_rate: 0.0010
# Epoch 118/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 6.2995e-04 - learning_rate: 0.0010
# Epoch 119/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 6.2252e-04 - learning_rate: 0.0010
# Epoch 120/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 6.1526e-04 - learning_rate: 0.0010
# Epoch 121/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 6.0812e-04 - learning_rate: 0.0010
# Epoch 122/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 6.0110e-04 - learning_rate: 0.0010
# Epoch 123/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 5.9423e-04 - learning_rate: 0.0010
# Epoch 124/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 5.8747e-04 - learning_rate: 0.0010
# Epoch 125/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 5.8084e-04 - learning_rate: 0.0010
# Epoch 126/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 5.7433e-04 - learning_rate: 0.0010
# Epoch 127/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 5.6794e-04 - learning_rate: 0.0010
# Epoch 128/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 5.6164e-04 - learning_rate: 0.0010
# Epoch 129/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 5.5547e-04 - learning_rate: 0.0010
# Epoch 130/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 5.4938e-04 - learning_rate: 0.0010
# Epoch 131/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 5.4342e-04 - learning_rate: 0.0010
# Epoch 132/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 5.3756e-04 - learning_rate: 0.0010
# Epoch 133/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 5.3178e-04 - learning_rate: 0.0010
# Epoch 134/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 5.2611e-04 - learning_rate: 0.0010
# Epoch 135/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 5.2053e-04 - learning_rate: 0.0010
# Epoch 136/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 5.1505e-04 - learning_rate: 0.0010
# Epoch 137/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 5.0966e-04 - learning_rate: 0.0010
# Epoch 138/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 5.0436e-04 - learning_rate: 0.0010
# Epoch 139/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 4.9915e-04 - learning_rate: 0.0010
# Epoch 140/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 4.9400e-04 - learning_rate: 0.0010
# Epoch 141/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 4.8896e-04 - learning_rate: 0.0010
# Epoch 142/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 4.8400e-04 - learning_rate: 0.0010
# Epoch 143/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 4.7911e-04 - learning_rate: 0.0010
# Epoch 144/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 4.7429e-04 - learning_rate: 0.0010
# Epoch 145/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 4.6955e-04 - learning_rate: 0.0010
# Epoch 146/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 4.6489e-04 - learning_rate: 0.0010
# Epoch 147/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 4.6029e-04 - learning_rate: 0.0010
# Epoch 148/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 4.5576e-04 - learning_rate: 0.0010
# Epoch 149/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 4.5131e-04 - learning_rate: 0.0010
# Epoch 150/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 4.4694e-04 - learning_rate: 0.0010
# Epoch 151/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 4.4261e-04 - learning_rate: 0.0010
# Epoch 152/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 4.3836e-04 - learning_rate: 0.0010
# Epoch 153/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 4.3416e-04 - learning_rate: 0.0010
# Epoch 154/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 4.3005e-04 - learning_rate: 0.0010
# Epoch 155/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 4.2598e-04 - learning_rate: 0.0010
# Epoch 156/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 4.2198e-04 - learning_rate: 0.0010
# Epoch 157/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 4.1803e-04 - learning_rate: 0.0010
# Epoch 158/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 4.1414e-04 - learning_rate: 0.0010
# Epoch 159/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 4.1030e-04 - learning_rate: 0.0010
# Epoch 160/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 4.0652e-04 - learning_rate: 0.0010
# Epoch 161/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 4.0280e-04 - learning_rate: 0.0010
# Epoch 162/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 3.9913e-04 - learning_rate: 0.0010
# Epoch 163/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.9551e-04 - learning_rate: 0.0010
# Epoch 164/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 3.9194e-04 - learning_rate: 0.0010
# Epoch 165/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 3.8843e-04 - learning_rate: 0.0010
# Epoch 166/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 3.8496e-04 - learning_rate: 0.0010
# Epoch 167/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 3.8154e-04 - learning_rate: 0.0010
# Epoch 168/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 3.7817e-04 - learning_rate: 0.0010
# Epoch 169/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 3.7483e-04 - learning_rate: 0.0010
# Epoch 170/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 3.7154e-04 - learning_rate: 0.0010
# Epoch 171/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 3.6829e-04 - learning_rate: 0.0010
# Epoch 172/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 3.6509e-04 - learning_rate: 0.0010
# Epoch 173/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 3.6194e-04 - learning_rate: 0.0010
# Epoch 174/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.5882e-04 - learning_rate: 0.0010
# Epoch 175/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.5574e-04 - learning_rate: 0.0010
# Epoch 176/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 3.5270e-04 - learning_rate: 0.0010
# Epoch 177/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 3.4971e-04 - learning_rate: 0.0010
# Epoch 178/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 3.4675e-04 - learning_rate: 0.0010
# Epoch 179/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.4383e-04 - learning_rate: 0.0010
# Epoch 180/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 3.4094e-04 - learning_rate: 0.0010
# Epoch 181/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.3810e-04 - learning_rate: 0.0010
# Epoch 182/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.3529e-04 - learning_rate: 0.0010
# Epoch 183/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 3.3251e-04 - learning_rate: 0.0010
# Epoch 184/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 3.2978e-04 - learning_rate: 0.0010
# Epoch 185/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 3.2707e-04 - learning_rate: 0.0010
# Epoch 186/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 3.2441e-04 - learning_rate: 0.0010
# Epoch 187/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 3.2176e-04 - learning_rate: 0.0010
# Epoch 188/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.1918e-04 - learning_rate: 0.0010
# Epoch 189/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 3.1662e-04 - learning_rate: 0.0010
# Epoch 190/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 3.1406e-04 - learning_rate: 0.0010
# Epoch 191/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 3.1156e-04 - learning_rate: 0.0010
# Epoch 192/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.0908e-04 - learning_rate: 0.0010
# Epoch 193/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 3.0663e-04 - learning_rate: 0.0010
# Epoch 194/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.0422e-04 - learning_rate: 0.0010
# Epoch 195/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 3.0184e-04 - learning_rate: 0.0010
# Epoch 196/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.9947e-04 - learning_rate: 0.0010
# Epoch 197/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.9714e-04 - learning_rate: 0.0010
# Epoch 198/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.9483e-04 - learning_rate: 0.0010
# Epoch 199/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.9256e-04 - learning_rate: 0.0010
# Epoch 200/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 2.9030e-04 - learning_rate: 0.0010
# Epoch 201/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.8809e-04 - learning_rate: 0.0010
# Epoch 202/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.8588e-04 - learning_rate: 0.0010
# Epoch 203/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.8371e-04 - learning_rate: 0.0010
# Epoch 204/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.8156e-04 - learning_rate: 0.0010
# Epoch 205/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.7943e-04 - learning_rate: 0.0010
# Epoch 206/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 2.7731e-04 - learning_rate: 0.0010
# Epoch 207/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.7524e-04 - learning_rate: 0.0010
# Epoch 208/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 2.7319e-04 - learning_rate: 0.0010
# Epoch 209/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.7116e-04 - learning_rate: 0.0010
# Epoch 210/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.6914e-04 - learning_rate: 0.0010
# Epoch 211/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 2.6716e-04 - learning_rate: 0.0010
# Epoch 212/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.6519e-04 - learning_rate: 0.0010
# Epoch 213/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.6325e-04 - learning_rate: 0.0010
# Epoch 214/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.6133e-04 - learning_rate: 0.0010
# Epoch 215/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.5943e-04 - learning_rate: 0.0010
# Epoch 216/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.5754e-04 - learning_rate: 0.0010
# Epoch 217/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.5568e-04 - learning_rate: 0.0010
# Epoch 218/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.5384e-04 - learning_rate: 0.0010
# Epoch 219/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 2.5201e-04 - learning_rate: 0.0010
# Epoch 220/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.5021e-04 - learning_rate: 0.0010
# Epoch 221/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.4843e-04 - learning_rate: 0.0010
# Epoch 222/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.4666e-04 - learning_rate: 0.0010
# Epoch 223/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 2.4492e-04 - learning_rate: 0.0010
# Epoch 224/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.4321e-04 - learning_rate: 0.0010
# Epoch 225/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.4150e-04 - learning_rate: 0.0010
# Epoch 226/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.3980e-04 - learning_rate: 0.0010
# Epoch 227/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.3814e-04 - learning_rate: 0.0010
# Epoch 228/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 2.3649e-04 - learning_rate: 0.0010
# Epoch 229/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.3485e-04 - learning_rate: 0.0010
# Epoch 230/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 2.3323e-04 - learning_rate: 0.0010
# Epoch 231/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.3164e-04 - learning_rate: 0.0010
# Epoch 232/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 2.3005e-04 - learning_rate: 0.0010
# Epoch 233/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.2850e-04 - learning_rate: 0.0010
# Epoch 234/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 2.2695e-04 - learning_rate: 0.0010
# Epoch 235/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 2.2540e-04 - learning_rate: 0.0010
# Epoch 236/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.2390e-04 - learning_rate: 0.0010
# Epoch 237/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 2.2239e-04 - learning_rate: 0.0010
# Epoch 238/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.2090e-04 - learning_rate: 0.0010
# Epoch 239/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.1943e-04 - learning_rate: 0.0010
# Epoch 240/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.1796e-04 - learning_rate: 0.0010
# Epoch 241/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.1652e-04 - learning_rate: 0.0010
# Epoch 242/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.1509e-04 - learning_rate: 0.0010
# Epoch 243/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.1368e-04 - learning_rate: 0.0010
# Epoch 244/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.1227e-04 - learning_rate: 0.0010
# Epoch 245/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 2.1089e-04 - learning_rate: 0.0010
# Epoch 246/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.0952e-04 - learning_rate: 0.0010
# Epoch 247/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.0816e-04 - learning_rate: 0.0010
# Epoch 248/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.0680e-04 - learning_rate: 0.0010
# Epoch 249/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.0548e-04 - learning_rate: 0.0010
# Epoch 250/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.0415e-04 - learning_rate: 0.0010
# Epoch 251/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.0284e-04 - learning_rate: 0.0010
# Epoch 252/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.0155e-04 - learning_rate: 0.0010
# Epoch 253/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.0026e-04 - learning_rate: 0.0010
# Epoch 254/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.9899e-04 - learning_rate: 0.0010
# Epoch 255/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.9774e-04 - learning_rate: 0.0010
# Epoch 256/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 1.9648e-04 - learning_rate: 0.0010
# Epoch 257/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.9525e-04 - learning_rate: 0.0010
# Epoch 258/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.9403e-04 - learning_rate: 0.0010
# Epoch 259/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.9280e-04 - learning_rate: 0.0010
# Epoch 260/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.9160e-04 - learning_rate: 0.0010
# Epoch 261/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.9040e-04 - learning_rate: 0.0010
# Epoch 262/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.8923e-04 - learning_rate: 0.0010
# Epoch 263/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.8806e-04 - learning_rate: 0.0010
# Epoch 264/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.8690e-04 - learning_rate: 0.0010
# Epoch 265/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.8577e-04 - learning_rate: 0.0010
# Epoch 266/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.8461e-04 - learning_rate: 0.0010
# Epoch 267/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 1.8348e-04 - learning_rate: 0.0010
# Epoch 268/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.8237e-04 - learning_rate: 0.0010
# Epoch 269/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.8127e-04 - learning_rate: 0.0010
# Epoch 270/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.8016e-04 - learning_rate: 0.0010
# Epoch 271/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.7907e-04 - learning_rate: 0.0010
# Epoch 272/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.7799e-04 - learning_rate: 0.0010
# Epoch 273/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.7702e-04 - learning_rate: 5.0000e-04
# Epoch 274/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.7648e-04 - learning_rate: 5.0000e-04
# Epoch 275/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.7595e-04 - learning_rate: 5.0000e-04
# Epoch 276/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.7542e-04 - learning_rate: 5.0000e-04
# Epoch 277/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.7491e-04 - learning_rate: 5.0000e-04
# Epoch 278/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.7438e-04 - learning_rate: 5.0000e-04
# Epoch 279/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.7386e-04 - learning_rate: 5.0000e-04
# Epoch 280/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.7334e-04 - learning_rate: 5.0000e-04
# Epoch 281/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.7283e-04 - learning_rate: 5.0000e-04
# Epoch 282/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.7232e-04 - learning_rate: 5.0000e-04
# Epoch 283/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.7180e-04 - learning_rate: 5.0000e-04
# Epoch 284/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.7130e-04 - learning_rate: 5.0000e-04
# Epoch 285/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.7078e-04 - learning_rate: 5.0000e-04
# Epoch 286/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.7028e-04 - learning_rate: 5.0000e-04
# Epoch 287/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.6977e-04 - learning_rate: 5.0000e-04
# Epoch 288/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.6926e-04 - learning_rate: 5.0000e-04
# Epoch 289/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.6877e-04 - learning_rate: 5.0000e-04
# Epoch 290/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.6826e-04 - learning_rate: 5.0000e-04
# Epoch 291/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.6776e-04 - learning_rate: 5.0000e-04
# Epoch 292/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.6726e-04 - learning_rate: 5.0000e-04
# Epoch 293/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.6677e-04 - learning_rate: 5.0000e-04
# Epoch 294/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.6627e-04 - learning_rate: 5.0000e-04
# Epoch 295/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.6578e-04 - learning_rate: 5.0000e-04
# Epoch 296/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.6530e-04 - learning_rate: 5.0000e-04
# Epoch 297/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.6480e-04 - learning_rate: 5.0000e-04
# Epoch 298/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.6431e-04 - learning_rate: 5.0000e-04
# Epoch 299/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.6383e-04 - learning_rate: 5.0000e-04
# Epoch 300/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.6334e-04 - learning_rate: 5.0000e-04
# Epoch 301/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.6285e-04 - learning_rate: 5.0000e-04
# Epoch 302/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.6237e-04 - learning_rate: 5.0000e-04
# Epoch 303/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.6189e-04 - learning_rate: 5.0000e-04
# Epoch 304/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.6141e-04 - learning_rate: 5.0000e-04
# Epoch 305/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.6093e-04 - learning_rate: 5.0000e-04
# Epoch 306/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.6047e-04 - learning_rate: 5.0000e-04
# Epoch 307/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 1.5998e-04 - learning_rate: 5.0000e-04
# Epoch 308/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.5951e-04 - learning_rate: 5.0000e-04
# Epoch 309/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.5904e-04 - learning_rate: 5.0000e-04
# Epoch 310/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 1.5858e-04 - learning_rate: 5.0000e-04
# Epoch 311/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 1.5811e-04 - learning_rate: 5.0000e-04
# Epoch 312/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.5763e-04 - learning_rate: 5.0000e-04
# Epoch 313/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.5717e-04 - learning_rate: 5.0000e-04
# Epoch 314/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.5672e-04 - learning_rate: 5.0000e-04
# Epoch 315/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.5625e-04 - learning_rate: 5.0000e-04
# Epoch 316/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 1.5580e-04 - learning_rate: 5.0000e-04
# Epoch 317/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.5533e-04 - learning_rate: 5.0000e-04
# Epoch 318/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.5488e-04 - learning_rate: 5.0000e-04
# Epoch 319/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.5441e-04 - learning_rate: 5.0000e-04
# Epoch 320/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.5395e-04 - learning_rate: 5.0000e-04
# Epoch 321/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 1.5351e-04 - learning_rate: 5.0000e-04
# Epoch 322/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.5306e-04 - learning_rate: 5.0000e-04
# Epoch 323/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.5263e-04 - learning_rate: 2.5000e-04
# Epoch 324/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.5240e-04 - learning_rate: 2.5000e-04
# Epoch 325/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.5218e-04 - learning_rate: 2.5000e-04
# Epoch 326/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.5197e-04 - learning_rate: 2.5000e-04
# Epoch 327/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.5173e-04 - learning_rate: 2.5000e-04
# Epoch 328/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.5151e-04 - learning_rate: 2.5000e-04
# Epoch 329/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.5128e-04 - learning_rate: 2.5000e-04
# Epoch 330/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.5107e-04 - learning_rate: 2.5000e-04
# Epoch 331/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.5084e-04 - learning_rate: 2.5000e-04
# Epoch 332/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.5061e-04 - learning_rate: 2.5000e-04
# Epoch 333/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.5040e-04 - learning_rate: 2.5000e-04
# Epoch 334/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.5018e-04 - learning_rate: 2.5000e-04
# Epoch 335/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.4995e-04 - learning_rate: 2.5000e-04
# Epoch 336/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.4973e-04 - learning_rate: 2.5000e-04
# Epoch 337/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.4951e-04 - learning_rate: 2.5000e-04
# Epoch 338/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.4928e-04 - learning_rate: 2.5000e-04
# Epoch 339/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.4906e-04 - learning_rate: 2.5000e-04
# Epoch 340/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.4883e-04 - learning_rate: 2.5000e-04
# Epoch 341/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.4861e-04 - learning_rate: 2.5000e-04
# Epoch 342/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.4839e-04 - learning_rate: 2.5000e-04
# Epoch 343/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.4816e-04 - learning_rate: 2.5000e-04
# Epoch 344/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.4795e-04 - learning_rate: 2.5000e-04
# Epoch 345/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.4772e-04 - learning_rate: 2.5000e-04
# Epoch 346/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.4751e-04 - learning_rate: 2.5000e-04
# Epoch 347/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.4728e-04 - learning_rate: 2.5000e-04
# Epoch 348/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.4706e-04 - learning_rate: 2.5000e-04
# Epoch 349/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.4684e-04 - learning_rate: 2.5000e-04
# Epoch 350/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.4662e-04 - learning_rate: 2.5000e-04
# Epoch 351/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.4640e-04 - learning_rate: 2.5000e-04
# Epoch 352/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.4618e-04 - learning_rate: 2.5000e-04
# Epoch 353/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.4595e-04 - learning_rate: 2.5000e-04
# Epoch 354/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.4573e-04 - learning_rate: 2.5000e-04
# Epoch 355/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.4551e-04 - learning_rate: 2.5000e-04
# Epoch 356/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.4530e-04 - learning_rate: 2.5000e-04
# Epoch 357/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.4507e-04 - learning_rate: 2.5000e-04
# Epoch 358/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.4486e-04 - learning_rate: 2.5000e-04
# Epoch 359/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.4464e-04 - learning_rate: 2.5000e-04
# Epoch 360/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.4442e-04 - learning_rate: 2.5000e-04
# Epoch 361/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.4420e-04 - learning_rate: 2.5000e-04
# Epoch 362/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.4398e-04 - learning_rate: 2.5000e-04
# Epoch 363/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.4375e-04 - learning_rate: 2.5000e-04
# Epoch 364/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.4354e-04 - learning_rate: 2.5000e-04
# Epoch 365/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.4332e-04 - learning_rate: 2.5000e-04
# Epoch 366/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.4311e-04 - learning_rate: 2.5000e-04
# Epoch 367/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.4288e-04 - learning_rate: 2.5000e-04
# Epoch 368/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.4267e-04 - learning_rate: 2.5000e-04
# Epoch 369/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.4244e-04 - learning_rate: 2.5000e-04
# Epoch 370/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.4223e-04 - learning_rate: 2.5000e-04
# Epoch 371/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.4201e-04 - learning_rate: 2.5000e-04
# Epoch 372/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.4180e-04 - learning_rate: 2.5000e-04
# Epoch 373/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.4157e-04 - learning_rate: 2.5000e-04
# Epoch 374/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.4136e-04 - learning_rate: 2.5000e-04
# Epoch 375/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.4114e-04 - learning_rate: 2.5000e-04
# Epoch 376/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.4092e-04 - learning_rate: 2.5000e-04
# Epoch 377/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.4072e-04 - learning_rate: 2.5000e-04
# Epoch 378/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.4048e-04 - learning_rate: 2.5000e-04
# Epoch 379/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.4027e-04 - learning_rate: 2.5000e-04
# Epoch 380/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.4006e-04 - learning_rate: 2.5000e-04
# Epoch 381/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3984e-04 - learning_rate: 2.5000e-04
# Epoch 382/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.3963e-04 - learning_rate: 2.5000e-04
# Epoch 383/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.3940e-04 - learning_rate: 2.5000e-04
# Epoch 384/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3918e-04 - learning_rate: 2.5000e-04
# Epoch 385/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3897e-04 - learning_rate: 2.5000e-04
# Epoch 386/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 1.3875e-04 - learning_rate: 2.5000e-04
# Epoch 387/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.3854e-04 - learning_rate: 2.5000e-04
# Epoch 388/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.3833e-04 - learning_rate: 2.5000e-04
# Epoch 389/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3811e-04 - learning_rate: 2.5000e-04
# Epoch 390/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 1.3789e-04 - learning_rate: 2.5000e-04
# Epoch 391/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.3768e-04 - learning_rate: 2.5000e-04
# Epoch 392/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.3748e-04 - learning_rate: 2.5000e-04
# Epoch 393/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.3725e-04 - learning_rate: 2.5000e-04
# Epoch 394/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3704e-04 - learning_rate: 2.5000e-04
# Epoch 395/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3682e-04 - learning_rate: 2.5000e-04
# Epoch 396/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3662e-04 - learning_rate: 2.5000e-04
# Epoch 397/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.3640e-04 - learning_rate: 2.5000e-04
# Epoch 398/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3618e-04 - learning_rate: 2.5000e-04
# Epoch 399/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3596e-04 - learning_rate: 2.5000e-04
# Epoch 400/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3575e-04 - learning_rate: 2.5000e-04
# Epoch 401/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3555e-04 - learning_rate: 1.2500e-04
# Epoch 402/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3546e-04 - learning_rate: 1.2500e-04
# Epoch 403/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3536e-04 - learning_rate: 1.2500e-04
# Epoch 404/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3525e-04 - learning_rate: 1.2500e-04
# Epoch 405/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.3514e-04 - learning_rate: 1.2500e-04
# Epoch 406/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.3503e-04 - learning_rate: 1.2500e-04
# Epoch 407/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.3493e-04 - learning_rate: 1.2500e-04
# Epoch 408/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3482e-04 - learning_rate: 1.2500e-04
# Epoch 409/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.3471e-04 - learning_rate: 1.2500e-04
# Epoch 410/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3460e-04 - learning_rate: 1.2500e-04
# Epoch 411/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3449e-04 - learning_rate: 1.2500e-04
# Epoch 412/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3439e-04 - learning_rate: 1.2500e-04
# Epoch 413/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3428e-04 - learning_rate: 1.2500e-04
# Epoch 414/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 1.3417e-04 - learning_rate: 1.2500e-04
# Epoch 415/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3407e-04 - learning_rate: 1.2500e-04
# Epoch 416/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3397e-04 - learning_rate: 1.2500e-04
# Epoch 417/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.3385e-04 - learning_rate: 1.2500e-04
# Epoch 418/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3374e-04 - learning_rate: 1.2500e-04
# Epoch 419/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3364e-04 - learning_rate: 1.2500e-04
# Epoch 420/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3353e-04 - learning_rate: 1.2500e-04
# Epoch 421/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3342e-04 - learning_rate: 1.2500e-04
# Epoch 422/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3331e-04 - learning_rate: 1.2500e-04
# Epoch 423/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.3320e-04 - learning_rate: 1.2500e-04
# Epoch 424/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3310e-04 - learning_rate: 1.2500e-04
# Epoch 425/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.3299e-04 - learning_rate: 1.2500e-04
# Epoch 426/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3288e-04 - learning_rate: 1.2500e-04
# Epoch 427/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3277e-04 - learning_rate: 1.2500e-04
# Epoch 428/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3266e-04 - learning_rate: 1.2500e-04
# Epoch 429/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3255e-04 - learning_rate: 1.2500e-04
# Epoch 430/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.3246e-04 - learning_rate: 1.2500e-04
# Epoch 431/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3234e-04 - learning_rate: 1.2500e-04
# Epoch 432/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 1.3222e-04 - learning_rate: 1.2500e-04
# Epoch 433/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.3213e-04 - learning_rate: 1.2500e-04
# Epoch 434/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3202e-04 - learning_rate: 1.2500e-04
# Epoch 435/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3191e-04 - learning_rate: 1.2500e-04
# Epoch 436/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3180e-04 - learning_rate: 1.2500e-04
# Epoch 437/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3169e-04 - learning_rate: 1.2500e-04
# Epoch 438/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3159e-04 - learning_rate: 1.2500e-04
# Epoch 439/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.3148e-04 - learning_rate: 1.2500e-04
# Epoch 440/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3137e-04 - learning_rate: 1.2500e-04
# Epoch 441/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.3127e-04 - learning_rate: 1.2500e-04
# Epoch 442/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3115e-04 - learning_rate: 1.2500e-04
# Epoch 443/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3104e-04 - learning_rate: 1.2500e-04
# Epoch 444/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3094e-04 - learning_rate: 1.2500e-04
# Epoch 445/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.3083e-04 - learning_rate: 1.2500e-04
# Epoch 446/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3072e-04 - learning_rate: 1.2500e-04
# Epoch 447/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.3061e-04 - learning_rate: 1.2500e-04
# Epoch 448/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3050e-04 - learning_rate: 1.2500e-04
# Epoch 449/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3039e-04 - learning_rate: 1.2500e-04
# Epoch 450/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.3028e-04 - learning_rate: 1.2500e-04
# Epoch 451/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.3018e-04 - learning_rate: 1.0000e-04
# Epoch 452/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.3009e-04 - learning_rate: 1.0000e-04
# Epoch 453/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 1.3000e-04 - learning_rate: 1.0000e-04
# Epoch 454/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.2992e-04 - learning_rate: 1.0000e-04
# Epoch 455/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.2983e-04 - learning_rate: 1.0000e-04
# Epoch 456/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.2974e-04 - learning_rate: 1.0000e-04
# Epoch 457/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.2966e-04 - learning_rate: 1.0000e-04
# Epoch 458/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.2957e-04 - learning_rate: 1.0000e-04
# Epoch 459/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.2948e-04 - learning_rate: 1.0000e-04
# Epoch 460/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.2939e-04 - learning_rate: 1.0000e-04
# Epoch 461/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.2930e-04 - learning_rate: 1.0000e-04
# Epoch 462/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.2922e-04 - learning_rate: 1.0000e-04
# Epoch 463/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.2913e-04 - learning_rate: 1.0000e-04
# Epoch 464/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.2904e-04 - learning_rate: 1.0000e-04
# Epoch 465/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.2896e-04 - learning_rate: 1.0000e-04
# Epoch 466/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.2886e-04 - learning_rate: 1.0000e-04
# Epoch 467/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 1.2878e-04 - learning_rate: 1.0000e-04
# Epoch 468/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.2870e-04 - learning_rate: 1.0000e-04
# Epoch 469/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.2861e-04 - learning_rate: 1.0000e-04
# Epoch 470/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.2851e-04 - learning_rate: 1.0000e-04
# Epoch 471/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.2842e-04 - learning_rate: 1.0000e-04
# Epoch 472/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.2834e-04 - learning_rate: 1.0000e-04
# Epoch 473/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.2826e-04 - learning_rate: 1.0000e-04
# Epoch 474/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.2816e-04 - learning_rate: 1.0000e-04
# Epoch 475/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 1.2806e-04 - learning_rate: 1.0000e-04
# Epoch 476/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.2799e-04 - learning_rate: 1.0000e-04
# Epoch 477/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.2789e-04 - learning_rate: 1.0000e-04
# Epoch 478/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.2781e-04 - learning_rate: 1.0000e-04
# Epoch 479/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.2771e-04 - learning_rate: 1.0000e-04
# Epoch 480/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.2762e-04 - learning_rate: 1.0000e-04
# Epoch 481/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.2754e-04 - learning_rate: 1.0000e-04
# Epoch 482/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.2744e-04 - learning_rate: 1.0000e-04
# Epoch 483/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.2736e-04 - learning_rate: 1.0000e-04
# Epoch 484/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.2728e-04 - learning_rate: 1.0000e-04
# Epoch 485/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.2719e-04 - learning_rate: 1.0000e-04
# Epoch 486/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.2709e-04 - learning_rate: 1.0000e-04
# Epoch 487/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.2700e-04 - learning_rate: 1.0000e-04
# Epoch 488/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.2691e-04 - learning_rate: 1.0000e-04
# Epoch 489/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.2683e-04 - learning_rate: 1.0000e-04
# Epoch 490/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.2674e-04 - learning_rate: 1.0000e-04
# Epoch 491/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.2665e-04 - learning_rate: 1.0000e-04
# Epoch 492/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.2656e-04 - learning_rate: 1.0000e-04
# Epoch 493/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.2647e-04 - learning_rate: 1.0000e-04
# Epoch 494/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.2638e-04 - learning_rate: 1.0000e-04
# Epoch 495/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.2629e-04 - learning_rate: 1.0000e-04
# Epoch 496/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.2620e-04 - learning_rate: 1.0000e-04
# Epoch 497/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 1.2610e-04 - learning_rate: 1.0000e-04
# Epoch 498/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.2602e-04 - learning_rate: 1.0000e-04
# Epoch 499/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.2593e-04 - learning_rate: 1.0000e-04
# Epoch 500/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.2584e-04 - learning_rate: 1.0000e-04
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000018C237A5750> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/stepWARNING:tensorflow:6 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000018C237A5750> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 0.825

# %%
import matplotlib.pyplot as plt

# you can retrieve the history of training to visualize the loss
loss = cnn_cls.history.history["loss"]
plt.plot(loss, color='blue')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Evolution of the training loss.")
plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

cnn_best = tf.keras.models.load_model("best_cnn.keras", compile=False)

# %%
#get conv weights of layer 1  
conv1_weights = cnn_best.layers[1].get_weights()[0]

#get conv weights of layer 2  
conv2_weights = cnn_best.layers[4].get_weights()[0]

fig,ax = plt.subplots(2,6,figsize=(20,7))

cmap = plt.get_cmap('tab20c')
values = np.linspace(0, 1, 18)
np.random.shuffle(values)

for i in range(6):
  ax[0,i].plot(conv1_weights[:,0,i],color=cmap(values[i]))
  ax[0,i].set_title('Conv layer 1, Filter ' + str(i+1))
  ax[1,i].plot(conv2_weights[:,0,i],color=cmap(values[6+i]))
  ax[1,i].set_title('Conv layer 2, Filter ' + str(i+1))
plt.tight_layout()
plt.show()

#os.remove("best_cnn.keras")

# %%
from aeon.regression.deep_learning import FCNRegressor
from sklearn.metrics import mean_squared_error

cnn_rgs = FCNRegressor(n_epochs=500)
cnn_rgs.fit(X_train_r, y_train_mtser)
cnn_rgs_preds = cnn_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, cnn_rgs_preds))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1.1258670359094693

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, cnn_rgs_preds, title="FCNRegressor Predictions")
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'FCNRegressor Predictions'}, xlabel='Actual values', ylabel='Predicted values'>)

# %%
from aeon.classification.deep_learning import  TimeCNNClassifier
from sklearn.metrics import accuracy_score

# n_epochs chooses the number of training iterations
# verbose show the network's detail and the logs of training
cnn_cls = TimeCNNClassifier(n_epochs=500, verbose=True, save_best_model=True, best_file_name="best_time_cnn")
cnn_cls.fit(X_train_c, y_train_mtsc)
cnn_cls_preds = cnn_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, cnn_cls_preds))
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 100, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 94, 6)          │           174 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d               │ (None, 31, 6)          │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 25, 12)         │           516 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d_1             │ (None, 8, 12)          │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 2)              │           194 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 884 (3.45 KB)
#  Trainable params: 884 (3.45 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5000 - loss: 0.2584
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5000 - loss: 0.2528
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5750 - loss: 0.2502
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2496
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5000 - loss: 0.2501
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5000 - loss: 0.2506
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.2507
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.2502
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5000 - loss: 0.2494
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2485
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5000 - loss: 0.2476
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2469
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5250 - loss: 0.2462
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5000 - loss: 0.2456
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5000 - loss: 0.2450
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5000 - loss: 0.2445
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2439
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2433
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2428
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2422
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5000 - loss: 0.2415
# Epoch 22/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2408
# Epoch 23/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2401
# Epoch 24/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2393
# Epoch 25/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5000 - loss: 0.2384
# Epoch 26/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5250 - loss: 0.2376
# Epoch 27/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5750 - loss: 0.2367
# Epoch 28/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6250 - loss: 0.2358
# Epoch 29/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7000 - loss: 0.2349
# Epoch 30/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7750 - loss: 0.2340
# Epoch 31/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7750 - loss: 0.2330
# Epoch 32/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8000 - loss: 0.2320
# Epoch 33/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8000 - loss: 0.2311
# Epoch 34/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8000 - loss: 0.2300
# Epoch 35/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8000 - loss: 0.2290
# Epoch 36/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8000 - loss: 0.2279
# Epoch 37/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8000 - loss: 0.2268
# Epoch 38/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8000 - loss: 0.2257
# Epoch 39/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8000 - loss: 0.2246
# Epoch 40/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8250 - loss: 0.2234
# Epoch 41/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8250 - loss: 0.2223
# Epoch 42/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8250 - loss: 0.2211
# Epoch 43/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8250 - loss: 0.2198
# Epoch 44/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8250 - loss: 0.2186
# Epoch 45/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8250 - loss: 0.2173
# Epoch 46/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8250 - loss: 0.2161
# Epoch 47/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8500 - loss: 0.2147
# Epoch 48/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8500 - loss: 0.2134
# Epoch 49/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8500 - loss: 0.2121
# Epoch 50/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8500 - loss: 0.2107
# Epoch 51/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8500 - loss: 0.2093
# Epoch 52/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8500 - loss: 0.2079
# Epoch 53/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8500 - loss: 0.2065
# Epoch 54/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8500 - loss: 0.2051
# Epoch 55/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8500 - loss: 0.2036
# Epoch 56/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8500 - loss: 0.2021
# Epoch 57/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8500 - loss: 0.2007
# Epoch 58/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8500 - loss: 0.1992
# Epoch 59/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8500 - loss: 0.1977
# Epoch 60/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8500 - loss: 0.1961
# Epoch 61/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8500 - loss: 0.1946
# Epoch 62/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8500 - loss: 0.1931
# Epoch 63/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8500 - loss: 0.1915
# Epoch 64/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8500 - loss: 0.1900
# Epoch 65/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8750 - loss: 0.1884
# Epoch 66/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1869
# Epoch 67/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1853
# Epoch 68/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9000 - loss: 0.1837
# Epoch 69/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1822
# Epoch 70/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1806
# Epoch 71/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1790
# Epoch 72/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1775
# Epoch 73/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1759
# Epoch 74/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1744
# Epoch 75/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1729
# Epoch 76/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1714
# Epoch 77/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1698
# Epoch 78/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1683
# Epoch 79/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1668
# Epoch 80/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1654
# Epoch 81/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1639
# Epoch 82/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1625
# Epoch 83/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1610
# Epoch 84/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1596
# Epoch 85/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1582
# Epoch 86/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1568
# Epoch 87/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1555
# Epoch 88/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1541
# Epoch 89/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1528
# Epoch 90/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1515
# Epoch 91/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9000 - loss: 0.1502
# Epoch 92/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1489
# Epoch 93/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1476
# Epoch 94/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1464
# Epoch 95/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1452
# Epoch 96/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9000 - loss: 0.1440
# Epoch 97/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1428
# Epoch 98/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9000 - loss: 0.1416
# Epoch 99/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1404
# Epoch 100/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1393
# Epoch 101/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9000 - loss: 0.1381
# Epoch 102/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1370
# Epoch 103/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1359
# Epoch 104/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1348
# Epoch 105/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1338
# Epoch 106/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1327
# Epoch 107/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1317
# Epoch 108/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1306
# Epoch 109/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1296
# Epoch 110/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1286
# Epoch 111/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1276
# Epoch 112/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9000 - loss: 0.1266
# Epoch 113/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1257
# Epoch 114/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1247
# Epoch 115/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1238
# Epoch 116/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1228
# Epoch 117/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1219
# Epoch 118/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1210
# Epoch 119/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1201
# Epoch 120/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.1192
# Epoch 121/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8750 - loss: 0.1183
# Epoch 122/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8750 - loss: 0.1174
# Epoch 123/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8750 - loss: 0.1165
# Epoch 124/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8750 - loss: 0.1157
# Epoch 125/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8750 - loss: 0.1148
# Epoch 126/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8750 - loss: 0.1140
# Epoch 127/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8750 - loss: 0.1131
# Epoch 128/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8750 - loss: 0.1123
# Epoch 129/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8750 - loss: 0.1114
# Epoch 130/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8750 - loss: 0.1106
# Epoch 131/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8750 - loss: 0.1098
# Epoch 132/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8750 - loss: 0.1090
# Epoch 133/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8750 - loss: 0.1082
# Epoch 134/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8750 - loss: 0.1074
# Epoch 135/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8750 - loss: 0.1066
# Epoch 136/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8750 - loss: 0.1058
# Epoch 137/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1050
# Epoch 138/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9000 - loss: 0.1042
# Epoch 139/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1034
# Epoch 140/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1027
# Epoch 141/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1019
# Epoch 142/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.1011
# Epoch 143/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9000 - loss: 0.1004
# Epoch 144/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.0996
# Epoch 145/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0989
# Epoch 146/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9000 - loss: 0.0981
# Epoch 147/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9000 - loss: 0.0974
# Epoch 148/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9000 - loss: 0.0966
# Epoch 149/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9000 - loss: 0.0959
# Epoch 150/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.0951
# Epoch 151/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0944
# Epoch 152/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0937
# Epoch 153/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.0929
# Epoch 154/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.0922
# Epoch 155/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0915
# Epoch 156/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9000 - loss: 0.0908
# Epoch 157/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0901
# Epoch 158/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0894
# Epoch 159/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9000 - loss: 0.0886
# Epoch 160/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0879
# Epoch 161/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0872
# Epoch 162/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0865
# Epoch 163/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0858
# Epoch 164/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.0852
# Epoch 165/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0845
# Epoch 166/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0838
# Epoch 167/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0831
# Epoch 168/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0824
# Epoch 169/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.0818
# Epoch 170/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9000 - loss: 0.0811
# Epoch 171/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9000 - loss: 0.0804
# Epoch 172/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9250 - loss: 0.0798
# Epoch 173/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9250 - loss: 0.0791
# Epoch 174/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9250 - loss: 0.0785
# Epoch 175/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9250 - loss: 0.0778
# Epoch 176/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9250 - loss: 0.0772
# Epoch 177/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9250 - loss: 0.0766
# Epoch 178/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9250 - loss: 0.0759
# Epoch 179/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9250 - loss: 0.0753
# Epoch 180/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9250 - loss: 0.0747
# Epoch 181/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9250 - loss: 0.0740
# Epoch 182/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9250 - loss: 0.0734
# Epoch 183/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9250 - loss: 0.0728
# Epoch 184/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9250 - loss: 0.0722
# Epoch 185/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9250 - loss: 0.0716
# Epoch 186/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9250 - loss: 0.0710
# Epoch 187/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9250 - loss: 0.0704
# Epoch 188/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9250 - loss: 0.0698
# Epoch 189/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9250 - loss: 0.0692
# Epoch 190/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9250 - loss: 0.0687
# Epoch 191/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9250 - loss: 0.0681
# Epoch 192/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9250 - loss: 0.0675
# Epoch 193/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9250 - loss: 0.0669
# Epoch 194/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9250 - loss: 0.0664
# Epoch 195/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9250 - loss: 0.0658
# Epoch 196/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9500 - loss: 0.0653
# Epoch 197/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9500 - loss: 0.0647
# Epoch 198/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9500 - loss: 0.0642
# Epoch 199/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9500 - loss: 0.0636
# Epoch 200/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9500 - loss: 0.0631
# Epoch 201/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9500 - loss: 0.0625
# Epoch 202/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9500 - loss: 0.0620
# Epoch 203/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9500 - loss: 0.0615
# Epoch 204/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9500 - loss: 0.0609
# Epoch 205/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9500 - loss: 0.0604
# Epoch 206/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9500 - loss: 0.0599
# Epoch 207/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9500 - loss: 0.0594
# Epoch 208/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0589
# Epoch 209/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9750 - loss: 0.0583
# Epoch 210/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0578
# Epoch 211/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9750 - loss: 0.0573
# Epoch 212/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9750 - loss: 0.0568
# Epoch 213/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9750 - loss: 0.0563
# Epoch 214/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9750 - loss: 0.0558
# Epoch 215/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9750 - loss: 0.0554
# Epoch 216/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0549
# Epoch 217/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0544
# Epoch 218/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0539
# Epoch 219/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0534
# Epoch 220/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9750 - loss: 0.0530
# Epoch 221/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9750 - loss: 0.0525
# Epoch 222/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9750 - loss: 0.0520
# Epoch 223/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9750 - loss: 0.0516
# Epoch 224/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0511
# Epoch 225/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9750 - loss: 0.0507
# Epoch 226/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9750 - loss: 0.0502
# Epoch 227/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9750 - loss: 0.0498
# Epoch 228/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0493
# Epoch 229/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0489
# Epoch 230/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0484
# Epoch 231/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9750 - loss: 0.0480
# Epoch 232/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9750 - loss: 0.0476
# Epoch 233/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9750 - loss: 0.0472
# Epoch 234/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0467
# Epoch 235/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9750 - loss: 0.0463
# Epoch 236/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9750 - loss: 0.0459
# Epoch 237/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0455
# Epoch 238/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0451
# Epoch 239/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0447
# Epoch 240/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0443
# Epoch 241/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0439
# Epoch 242/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0435
# Epoch 243/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0431
# Epoch 244/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0428
# Epoch 245/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0424
# Epoch 246/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0420
# Epoch 247/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0416
# Epoch 248/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0413
# Epoch 249/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0409
# Epoch 250/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0406
# Epoch 251/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0402
# Epoch 252/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0398
# Epoch 253/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0395
# Epoch 254/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0391
# Epoch 255/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0388
# Epoch 256/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0385
# Epoch 257/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0381
# Epoch 258/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0378
# Epoch 259/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0375
# Epoch 260/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0371
# Epoch 261/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0368
# Epoch 262/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0365
# Epoch 263/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0362
# Epoch 264/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0359
# Epoch 265/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0356
# Epoch 266/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0353
# Epoch 267/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0349
# Epoch 268/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0346
# Epoch 269/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0343
# Epoch 270/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0340
# Epoch 271/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0338
# Epoch 272/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0335
# Epoch 273/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0332
# Epoch 274/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0329
# Epoch 275/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0326
# Epoch 276/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0323
# Epoch 277/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0320
# Epoch 278/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0318
# Epoch 279/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0315
# Epoch 280/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0312
# Epoch 281/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0310
# Epoch 282/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0307
# Epoch 283/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0304
# Epoch 284/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0302
# Epoch 285/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0299
# Epoch 286/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0297
# Epoch 287/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0294
# Epoch 288/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0292
# Epoch 289/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0289
# Epoch 290/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0287
# Epoch 291/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0284
# Epoch 292/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0282
# Epoch 293/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0279
# Epoch 294/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0277
# Epoch 295/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0275
# Epoch 296/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0272
# Epoch 297/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0270
# Epoch 298/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0268
# Epoch 299/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0266
# Epoch 300/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0263
# Epoch 301/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0261
# Epoch 302/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0259
# Epoch 303/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0257
# Epoch 304/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0255
# Epoch 305/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0252
# Epoch 306/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0250
# Epoch 307/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0248
# Epoch 308/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0246
# Epoch 309/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0244
# Epoch 310/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0242
# Epoch 311/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0240
# Epoch 312/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0238
# Epoch 313/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0236
# Epoch 314/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0234
# Epoch 315/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0232
# Epoch 316/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0230
# Epoch 317/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0229
# Epoch 318/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0227
# Epoch 319/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0225
# Epoch 320/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0223
# Epoch 321/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0221
# Epoch 322/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0219
# Epoch 323/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0218
# Epoch 324/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0216
# Epoch 325/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0214
# Epoch 326/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0212
# Epoch 327/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0211
# Epoch 328/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0209
# Epoch 329/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0207
# Epoch 330/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0205
# Epoch 331/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0204
# Epoch 332/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0202
# Epoch 333/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0201
# Epoch 334/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0199
# Epoch 335/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0197
# Epoch 336/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0196
# Epoch 337/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0194
# Epoch 338/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0193
# Epoch 339/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0191
# Epoch 340/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0190
# Epoch 341/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0188
# Epoch 342/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0187
# Epoch 343/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0185
# Epoch 344/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0184
# Epoch 345/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0182
# Epoch 346/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0181
# Epoch 347/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0179
# Epoch 348/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0178
# Epoch 349/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0177
# Epoch 350/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0175
# Epoch 351/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0174
# Epoch 352/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0173
# Epoch 353/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0171
# Epoch 354/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0170
# Epoch 355/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0169
# Epoch 356/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0167
# Epoch 357/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 358/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0165
# Epoch 359/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0163
# Epoch 360/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0162
# Epoch 361/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0161
# Epoch 362/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0160
# Epoch 363/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0158
# Epoch 364/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0157
# Epoch 365/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0156
# Epoch 366/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0155
# Epoch 367/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0154
# Epoch 368/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0153
# Epoch 369/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0151
# Epoch 370/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0150
# Epoch 371/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0149
# Epoch 372/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0148
# Epoch 373/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0147
# Epoch 374/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0146
# Epoch 375/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0145
# Epoch 376/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0144
# Epoch 377/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0143
# Epoch 378/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 379/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 380/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 381/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 382/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0137
# Epoch 383/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 384/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 385/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 386/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 387/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 388/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 389/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 390/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 391/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 392/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 393/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 394/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 395/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 396/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 397/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 398/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 399/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 400/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 401/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 402/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 403/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 404/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 405/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 406/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 407/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 408/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 409/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0113
# Epoch 410/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0112
# Epoch 411/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0112
# Epoch 412/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 413/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 414/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0109
# Epoch 415/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 416/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 417/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 418/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 419/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 420/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0105
# Epoch 421/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 422/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 423/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 424/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 425/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 426/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 427/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 428/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 429/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 430/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0098
# Epoch 431/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 432/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 433/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 434/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 435/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 436/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 437/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0093
# Epoch 438/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0093
# Epoch 439/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 440/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 441/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 442/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 443/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 444/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 445/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 446/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 447/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 448/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 449/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 450/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 451/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 452/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 453/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 454/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 455/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 456/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 457/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 458/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 459/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 460/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 461/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 462/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 463/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 464/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 465/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 466/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 467/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 468/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 469/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 470/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 471/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 472/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 473/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 474/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 475/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 476/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 477/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 478/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 479/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 480/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 481/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 482/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 483/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 484/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 485/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 486/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 487/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 488/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 489/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 490/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 491/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 492/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 493/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 494/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 495/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 496/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 497/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 498/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 499/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 500/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0063
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 0.625

# %%
cnn_t_best = tf.keras.models.load_model("best_time_cnn.keras", compile=False)
cnn_t_best.layers
# Out:
# [<InputLayer name=input_layer_4, built=True>,
#  <Conv1D name=conv1d_6, built=True>,
#  <AveragePooling1D name=average_pooling1d, built=True>,
#  <Conv1D name=conv1d_7, built=True>,
#  <AveragePooling1D name=average_pooling1d_1, built=True>,
#  <Flatten name=flatten_2, built=True>,
#  <Dense name=dense_10, built=True>]

# %%
#get conv weights of layer 1  
conv1_weights = cnn_t_best.layers[1].get_weights()[0]

#get conv weights of layer 2  
conv2_weights = cnn_t_best.layers[3].get_weights()[0]

fig,ax = plt.subplots(2,6,figsize=(20,7))

cmap = plt.get_cmap('tab20c')
values = np.linspace(0, 1, 18)
np.random.shuffle(values)

for i in range(6):
  ax[0,i].plot(conv1_weights[:,0,i],color=cmap(values[i]))
  ax[0,i].set_title('Conv layer 1, Filter ' + str(i+1))
  ax[1,i].plot(conv2_weights[:,0,i],color=cmap(values[6+i]))
  ax[1,i].set_title('Conv layer 2, Filter ' + str(i+1))
plt.tight_layout()
plt.show()

#os.remove("best_cnn.keras")

# %%
from aeon.regression.deep_learning import  TimeCNNRegressor
from sklearn.metrics import mean_squared_error

cnn_rgs = TimeCNNRegressor(n_epochs=500)
cnn_rgs.fit(X_train_r, y_train_mtser)
cnn_rgs_preds = cnn_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, cnn_rgs_preds))

plot_scatter_predictions(y_test_mtser, cnn_rgs_preds, title="TimeCNNRegressor Predictions")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1.4492177907419677
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'TimeCNNRegressor Predictions'}, xlabel='Actual values', ylabel='Predicted values'>)

# %% [markdown]
# # Упражнения <a id='tasks'></a>
#
# 1. Взять выбранные для лабы 9 набор(ы) данных. Можно взять разные наборы для классификации/регрессии (но причину надо будет обосновать)
#
# 2. Отрисовать данные
#
# 3. Попробовать все методы классификации и регрессии, описанные в блоноте:
#     Distance-based
#     Свертки (модели семейства Rocket и Hydra)
#     Feature-based
#     Deep Learning
#
#     Для каждого подхода обучть не менее 3х разных моделей для классификации и регрессии.

# %%
from aeon.datasets import load_classification

X_train, y_train = load_classification("GunPoint", split="TRAIN")
X_test, y_test = load_classification("GunPoint", split="TEST")

print(f"Train: {X_train.shape}, Test: {X_test.shape}")
# Out:
# Train: (50, 1, 150), Test: (150, 1, 150)

# %%
plt.figure(figsize=(10, 3))
for i in range(3):
    plt.plot(X_train[i].squeeze(), label=f'Class {y_train[i]}')
plt.title('GunPoint')
plt.legend()
plt.show()

# %%
classification_results = {}

# %% [markdown]
# ## 3 Distance-based models

# %%
from aeon.distances import squared_pairwise_distance, mp_distance, msm_distance

distances = [squared_pairwise_distance, mp_distance, msm_distance]
for distance in distances:
    model = KNeighborsTimeSeriesClassifier(n_neighbors=3, distance=distance).fit(X_train, y_train)
    accuracy = accuracy_score(y_test, model.predict(X_test))
    classification_results[f'KNeighborsTimeSeriesClassifier {distance.__name__}'] = accuracy
    print(f"KNeighborsTimeSeriesClassifier {distance.__name__}: {round(accuracy, 4)}")
# Out:
# KNeighborsTimeSeriesClassifier squared_pairwise_distance: 0.9133
# KNeighborsTimeSeriesClassifier mp_distance: 0.92
# KNeighborsTimeSeriesClassifier msm_distance: 0.9667

# %% [markdown]
# ## 3 Convolution-based models

# %%
from aeon.classification.convolution_based import RocketClassifier, HydraClassifier, MiniRocketClassifier

model_classes = [MiniRocketClassifier, HydraClassifier, RocketClassifier]

for model_class in model_classes:    
    model = model_class(n_kernels=100).fit(X_train, y_train)
    accuracy = model.score(X_test, y_test)
    classification_results[f'{model_class.__name__}'] = accuracy
    print(f"{model_class.__name__}: {round(accuracy, 6)}")
# Out:
# MiniRocketClassifier: 0.966667
# HydraClassifier: 1.0
# RocketClassifier: 0.993333

# %% [markdown]
# ## 3 Feature-based models

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier

estimators = [KNeighborsClassifier, RandomForestClassifier, GradientBoostingClassifier]
for estimator in estimators:
    model = Catch22Classifier(estimator=estimator()).fit(X_train, y_train)
    accuracy = accuracy_score(y_test, model.predict(X_test))
    classification_results[f'Catch22Classifier with {estimator.__name__}'] = accuracy
    print(f"Catch22Classifier with {estimator.__name__}: {round(accuracy, 4)}")
# Out:
# Catch22Classifier with KNeighborsClassifier: 0.7933
# Catch22Classifier with RandomForestClassifier: 0.94
# Catch22Classifier with GradientBoostingClassifier: 0.8867

# %% [markdown]
# ## 3 Deep learning models

# %%
n_epochs_list = [10, 20, 30]
n_units_list = [50, 100, 150]

for n_epochs, n_units in zip(n_epochs_list, n_units_list):
    model = MLPClassifier(n_epochs=n_epochs, n_units=n_units).fit(X_train, y_train)
    accuracy = accuracy_score(y_test, model.predict(X_test))
    classification_results[f'MLPClassifier with n_epochs={n_epochs}, n_units={n_units}'] = accuracy
    print(f"MLPClassifier with n_epochs={n_epochs}, n_units={n_units}: {round(accuracy, 4)}")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# MLPClassifier with n_epochs=10, n_units=50: 0.5067
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# MLPClassifier with n_epochs=20, n_units=100: 0.4933
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MLPClassifier with n_epochs=30, n_units=150: 0.56

# %% [markdown]
# ## Сравнение моделей

# %%
plt.figure(figsize=(16, 10))
accuracies = list(classification_results.values())
colors = ['lime' if acc == max(accuracies) else 'maroon' for acc in accuracies]
plt.bar(list(classification_results.keys()), accuracies, color=colors)
plt.xlabel('Accuracy')
plt.title('Classification')
plt.axhline(y=0.95, color='red', linestyle='--', alpha=0.5, label='Baseline')
plt.xticks(rotation=25, ha='right')
plt.tight_layout()
plt.legend()
plt.show()
